# %%
# Import dependencies
import requests
import pprint
import pandas as pd
import json
import os
import csv
from pymongo import MongoClient
from pprint import pprint

# %% [markdown]
# ## Property Listings Data

# %%
# Parameters for getting all the Property data from Houski Api
params = {}
params['api_key'] = '698c8c20-7e89-4f9b-a8c0-ac7fd9d76313'
params['city'] = 'toronto'
params['country_abbreviation'] = 'ca'
params['province_abbreviation'] = 'on'
params['results_per_page'] = '370'
params['select'] = 'address,latitude,longitude,city,province,postal_code,direction_facing,den,list_price,estimate_list_price,property_taxes,land_area_sq_m,interior_sq_m,bedroom,bathroom_full,bathroom_half,construction_year,property_taxes,score_education,score_food_and_drink,score_bicycle,score_entertainment,score_safety,score_shopping,score_traffic,score_transit,score_walkability'

# Make the API request
response = requests.get('https://api.houski.ca/properties', params=params)

# Extract the json result
if response.status_code == 200:
    json_data = response.json()
    pprint(json_data)
else:
    print(f'Failed to get data: {response}')
# Out:
# {'cache_hit': False,
#  'cost_cents': 965.6998901367188,
#  'data': [{'address': '227 Old Forest Hill Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 6,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 904014,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.70151138305664,
#            'longitude': -79.43286895751953,
#            'postal_code': 'M5P2R5',
#            'property_id': '409d2421dde3d345',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '150 Old Forest Hill Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 6,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 879095,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.702110290527344,
#            'longitude': -79.4246826171875,
#            'postal_code': 'M5P2R5',
#            'property_id': '8b2a9b4ab2f79b12',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2811 Dufferin Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1336066,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.705440521240234,
#            'longitude': -79.45207977294922,
#            'postal_code': 'V0V0V0',
#            'property_id': '1afe2444031d8bdc',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '31 Symington Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1193032,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.65834045410156,
#            'longitude': -79.44793701171875,
#            'postal_code': 'V0V0V0',
#            'property_id': '7058235d522380de',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1050 Wilson Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 874292,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.72853088378906,
#            'longitude': -79.47943878173828,
#            'postal_code': 'V0V0V0',
#            'property_id': '2c59a9deea3531a9',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '137 Roxborough Street E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1874484,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.678958892822266,
#            'longitude': -79.38365173339844,
#            'postal_code': 'V0V0V0',
#            'property_id': '13df881c7940116f',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '37A Charles Street W',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 889454,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.668209075927734,
#            'longitude': -79.38768768310547,
#            'postal_code': 'V0V0V0',
#            'property_id': '1bc6222a1ee6b008',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2084 Queen Street E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1972692,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.671058654785156,
#            'longitude': -79.29644012451172,
#            'postal_code': 'V0V0V0',
#            'property_id': 'e7554e878d07a611',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3 Kingsgate Crescent',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1385878,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.68574142456055,
#            'longitude': -79.53108215332031,
#            'postal_code': 'M9P3E2',
#            'property_id': '4a1edcc368463a01',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3 Caley Terrace',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 893800,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.79396057128906,
#            'longitude': -79.20185852050781,
#            'postal_code': 'V0V0V0',
#            'property_id': 'ce3581ca7466951b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '71 Bainbridge Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1017140,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.749290466308594,
#            'longitude': -79.44342803955078,
#            'postal_code': 'V0V0V0',
#            'property_id': '40f7c655a2707bba',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '349 Manning Avenue',
#            'bathroom_full': 5,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 2703734,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.65496826171875,
#            'longitude': -79.41216278076172,
#            'postal_code': 'M6J2K8',
#            'property_id': '38038fb6d03945b7',
#            'property_taxes': 10154,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '69 Pauline Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1348981,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.66167068481445,
#            'longitude': -79.4382095336914,
#            'postal_code': 'V0V0V0',
#            'property_id': 'e916c0ccf0bd5a39',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '7 Trailview Terrace',
#            'bathroom_full': 3,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 923241,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.80807113647461,
#            'longitude': -79.18074035644531,
#            'postal_code': 'M1B6H3',
#            'property_id': '161069a7d783621f',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '272 Crawford Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1931105,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.65068817138672,
#            'longitude': -79.41761016845703,
#            'postal_code': 'V0V0V0',
#            'property_id': 'f0e27ff4f562c120',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '109 Wallace Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1378703,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.66294860839844,
#            'longitude': -79.44066619873047,
#            'postal_code': 'V0V0V0',
#            'property_id': '7a919d9f28729db6',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '20 Melrose Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1808401,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.73295974731445,
#            'longitude': -79.40518951416016,
#            'postal_code': 'V0V0V0',
#            'property_id': 'f4d8cc5a35b3039b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '8 Norris Crescent',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 937588,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.61075973510742,
#            'longitude': -79.48927307128906,
#            'postal_code': 'V0V0V0',
#            'property_id': 'fb29cec8c634fbf3',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '30 Yachters Lane',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 957545,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.620849609375,
#            'longitude': -79.48568725585938,
#            'postal_code': 'V0V0V0',
#            'property_id': '837dbf5aa98a07f6',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '71 Anndale Drive',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 849559,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.76137924194336,
#            'longitude': -79.40274047851562,
#            'postal_code': 'M2N2W7',
#            'property_id': '4d85fa4473278626',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '63 Bowhill Crescent',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1166772,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.78633117675781,
#            'longitude': -79.33326721191406,
#            'postal_code': 'M2J3S2',
#            'property_id': '423ef62fde80913c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '56 Truman Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 5,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 856738,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.761329650878906,
#            'longitude': -79.38327026367188,
#            'postal_code': 'M2L2L4',
#            'property_id': 'd42b15b0593b2c49',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '141 Vine Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1647591,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.666481018066406,
#            'longitude': -79.46929931640625,
#            'postal_code': 'V0V0V0',
#            'property_id': '968b813cd6f7ecfa',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2 Mahoney Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1360597,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.691261291503906,
#            'longitude': -79.49978637695312,
#            'postal_code': 'V0V0V0',
#            'property_id': 'd62e4f558514b67',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1016 Dixon Road',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 969294,
#            'interior_sq_m': 59.64375305175781,
#            'latitude': 43.70125961303711,
#            'longitude': -79.52838897705078,
#            'postal_code': 'M9R1S8',
#            'property_id': 'cf4a112b03f6ca6e',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '16 Cavell Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1844904,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.618709564208984,
#            'longitude': -79.49217987060547,
#            'postal_code': 'M4K1L6',
#            'property_id': '7c6b76a96b4b9d74',
#            'property_taxes': 7149,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '303 Craven Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 966609,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.67045974731445,
#            'longitude': -79.3201675415039,
#            'postal_code': 'M4L2Z4',
#            'property_id': 'bba8f41cffbfd02f',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '48 Millhouse Crescent',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 2,
#            'direction_facing': 'South',
#            'estimate_list_price': 871125,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.804508209228516,
#            'longitude': -79.17355346679688,
#            'postal_code': 'M1B2E4',
#            'property_id': '74245105b927264b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '33 Marlebon Road',
#            'bathroom_full': 4,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1159196,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.748939514160156,
#            'longitude': -79.60249328613281,
#            'postal_code': 'M9V3V8',
#            'property_id': '94f8b67cb9893c2c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '88 Davenport Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1878515,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.6732292175293,
#            'longitude': -79.39032745361328,
#            'postal_code': 'M5R0B5',
#            'property_id': '888c3db44a37d300',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '101 Powell Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1652681,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.73686981201172,
#            'longitude': -79.46775817871094,
#            'postal_code': 'M3K1M7',
#            'property_id': '2e98d25eb3ff2ce6',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '10 Dundurn Crescent',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 882118,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.68355178833008,
#            'longitude': -79.43287658691406,
#            'postal_code': 'V0V0V0',
#            'property_id': '1c3c34444f8c2ccd',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '199 Grace Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1740752,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.65665054321289,
#            'longitude': -79.41596984863281,
#            'postal_code': 'V0V0V0',
#            'property_id': '286b2457f0b7adda',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '18 Scotia Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1008978,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.69557189941406,
#            'longitude': -79.27323913574219,
#            'postal_code': 'V0V0V0',
#            'property_id': '705af93e0bf15634',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '158 Hampton Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1779857,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.676429748535156,
#            'longitude': -79.35266876220703,
#            'postal_code': 'V0V0V0',
#            'property_id': 'ec8f9250d2ebb5af',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '43 Waxham Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 870860,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.725059509277344,
#            'longitude': -79.58171081542969,
#            'postal_code': 'M9W3L3',
#            'property_id': 'ac560d8987aba70d',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '495 Sackville Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 2279902,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.66947937011719,
#            'longitude': -79.36663055419922,
#            'postal_code': 'V0V0V0',
#            'property_id': '57007c9a94c65f31',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '354 Richmond Street E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 991827,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.654090881347656,
#            'longitude': -79.368408203125,
#            'postal_code': 'V0V0V0',
#            'property_id': 'a41b4fc10ec275c3',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '5 Olean Court',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 832661,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.79914093017578,
#            'longitude': -79.37953186035156,
#            'postal_code': 'V0V0V0',
#            'property_id': 'ca2d48e285f1e863',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '125 Merrill Avenue E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1003501,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.683109283447266,
#            'longitude': -79.31233215332031,
#            'postal_code': 'V0V0V0',
#            'property_id': '78df6a6a36fc6b4b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '41 Benlight Crescent',
#            'bathroom_full': 4,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1198990,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.76227951049805,
#            'longitude': -79.23863983154297,
#            'postal_code': 'M1H1P4',
#            'property_id': 'bf747db4dc73d32d',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '59 Moreau Trl',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1017105,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.70933151245117,
#            'longitude': -79.28304290771484,
#            'postal_code': 'V0V0V0',
#            'property_id': '6f47ec31ae1620cc',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '7 Sidford Court',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1231900,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.6591796875,
#            'longitude': -79.49723815917969,
#            'postal_code': 'V0V0V0',
#            'property_id': 'f506bb7046805bac',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '13 Quince Appleway',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1003248,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.746978759765625,
#            'longitude': -79.31185150146484,
#            'postal_code': 'M3A2E6',
#            'property_id': '60fa857239c3e325',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '44 Kirknewton Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1167562,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.692378997802734,
#            'longitude': -79.4513931274414,
#            'postal_code': 'M6E3X9',
#            'property_id': 'd2627efad9425e6f',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '49 Winners Circle',
#            'bathroom_full': 4,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1685139,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.665531158447266,
#            'longitude': -79.30912017822266,
#            'postal_code': 'M4L3Y7',
#            'property_id': 'a2e670ed7b7c7772',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '26 Orlando Boulevard',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 2010929,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.757568359375,
#            'longitude': -79.30654907226562,
#            'postal_code': 'M1R3N5',
#            'property_id': 'f4136a1dec5dc101',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '19 Muirdale Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1488435,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.683311462402344,
#            'longitude': -79.54885864257812,
#            'postal_code': 'V0V0V0',
#            'property_id': '41f7e8a91e3809e2',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '21 Callowhill Drive',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 925049,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.68014907836914,
#            'longitude': -79.56202697753906,
#            'postal_code': 'M9R3K9',
#            'property_id': 'e99323965d7d8ad8',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '6 Tampa Terrace',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 838347,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.74168014526367,
#            'longitude': -79.54210662841797,
#            'postal_code': 'M9M1T9',
#            'property_id': '6e67bc82619ca65a',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '56 Rochester Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 2817688,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.724449157714844,
#            'longitude': -79.39167022705078,
#            'postal_code': 'V0V0V0',
#            'property_id': '4b199b72a29ec635',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '18 Gorman Park Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1902288,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.74763107299805,
#            'longitude': -79.44650268554688,
#            'postal_code': 'M3H3K7',
#            'property_id': 'abb01b629e945cc5',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '16 Kylemore Crescent',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1374432,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.68465042114258,
#            'longitude': -79.53076171875,
#            'postal_code': 'M9P1C8',
#            'property_id': '37d9fca718ca355c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2A Roseneath Gardens',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1297671,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.68233108520508,
#            'longitude': -79.43508911132812,
#            'postal_code': 'M6C3X5',
#            'property_id': '1129df19a2ce194f',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '11 Waldock Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 887128,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.75822067260742,
#            'longitude': -79.19178771972656,
#            'postal_code': 'V0V0V0',
#            'property_id': '5ecae447b55c6d02',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '308 Ranee Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 924958,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.72275924682617,
#            'longitude': -79.45208740234375,
#            'postal_code': 'V0V0V0',
#            'property_id': '47d87f11f588e3d7',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
# ...
#            'estimate_list_price': 1062139,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.683868408203125,
#            'longitude': -79.2901382446289,
#            'postal_code': 'V0V0V0',
#            'property_id': 'd340307cd96d4c8d',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '461 Plains Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1417227,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.696678161621094,
#            'longitude': -79.32440185546875,
#            'postal_code': 'M4C2Y4',
#            'property_id': 'cae895e0888ce7e9',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '27 Sorlyn Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1431697,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.70726013183594,
#            'longitude': -79.49165344238281,
#            'postal_code': 'V0V0V0',
#            'property_id': 'a5347bb9db89b81',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '189 Beatrice Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1924525,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.65604019165039,
#            'longitude': -79.41712188720703,
#            'postal_code': 'V0V0V0',
#            'property_id': 'c475b1eab1d37c6d',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '19 Burnaby Boulevard',
#            'bathroom_full': 4,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 2133181,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.70549011230469,
#            'longitude': -79.40751647949219,
#            'postal_code': 'M5N1G3',
#            'property_id': 'ad5936cac12a72c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '14 Fulham Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1051242,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.78432083129883,
#            'longitude': -79.26869201660156,
#            'postal_code': 'V0V0V0',
#            'property_id': 'de351140d53c619a',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '15 Bain Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1753985,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.670528411865234,
#            'longitude': -79.35273742675781,
#            'postal_code': 'V0V0V0',
#            'property_id': 'e5d45c7275034be',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '130 Beatrice Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1826949,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.65399932861328,
#            'longitude': -79.41654205322266,
#            'postal_code': 'V0V0V0',
#            'property_id': '596de5eebba04cee',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '54 Caronridge Crescent',
#            'bathroom_full': 3,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1162100,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.78800964355469,
#            'longitude': -79.3203125,
#            'postal_code': 'M1W1L1',
#            'property_id': '33709e439560aa67',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '668 Davenport Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 2197153,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.676971435546875,
#            'longitude': -79.41493225097656,
#            'postal_code': 'M5R0B5',
#            'property_id': 'f65ae78fd7b3c800',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '228 Alfred Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 2001408,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.76887130737305,
#            'longitude': -79.39424896240234,
#            'postal_code': 'V0V0V0',
#            'property_id': 'f862c26fe076efc3',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '209 Keele Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1410880,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.65996170043945,
#            'longitude': -79.4618911743164,
#            'postal_code': 'V0V0V0',
#            'property_id': '4bc583ea39f265bf',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1266 College Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1549187,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.651458740234375,
#            'longitude': -79.43900299072266,
#            'postal_code': 'V0V0V0',
#            'property_id': '373de631210fae05',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '90 Cleta Drive',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 5,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1465999,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.72349166870117,
#            'longitude': -79.2630615234375,
#            'postal_code': 'M1K3G6',
#            'property_id': 'b72a5953eae4cb4c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '9 Tanbark Crescent',
#            'bathroom_full': 5,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 2104255,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.74374008178711,
#            'longitude': -79.36567687988281,
#            'postal_code': 'M3B1N7',
#            'property_id': '16ec8bc05d0662fc',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '107 Grandview Way',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1127067,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.77497100830078,
#            'longitude': -79.41161346435547,
#            'postal_code': 'M2N6V6',
#            'property_id': '57e2dc32051ec445',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2 Brule Terrace',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 977968,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.64693069458008,
#            'longitude': -79.48889923095703,
#            'postal_code': 'V0V0V0',
#            'property_id': '96bc22d826d08179',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '60 Glen Agar Drive',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1932728,
#            'interior_sq_m': 104.58000183105469,
#            'latitude': 43.66477966308594,
#            'longitude': -79.55622100830078,
#            'postal_code': 'M9B5L2',
#            'property_id': '2235f6ebdff86a1f',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9}],
#  'error': '',
#  'pagination': {'current_page': 1,
#                 'has_next_page': True,
#                 'has_previous_page': False,
#                 'page_total': 1503},
#  'price_quote': False,
#  'result_total': 555873,
#  'time_ms': 64,
#  'ui_info': {'city': 'Toronto',
#              'city_id': '6cdbdee2492718ed',
#              'city_link': 'ca/on/toronto',
#              'city_slug': 'toronto',
#              'country': 'Canada',
#              'country_abbreviation': 'CA',
#              'country_abbreviation_id': '9ace2b6431b7f1be',
#              'country_abbreviation_link': 'ca',
#              'country_slug': 'canada',
#              'province': 'Ontario',
#              'province_abbreviation': 'ON',
#              'province_abbreviation_id': '146699ee774499d3',
#              'province_abbreviation_link': 'ca/on',
#              'province_slug': 'ontario'}}

# %%
# Extract the data from Json
Property_data=json_data["data"]
print(Property_data)
# Out:
# [{'address': '227 Old Forest Hill Road', 'bathroom_full': 2, 'bathroom_half': 0, 'bedroom': 6, 'city': 'Toronto', 'construction_year': 1978, 'den': 1, 'direction_facing': 'South', 'estimate_list_price': 904014, 'interior_sq_m': 104.58000183105469, 'latitude': 43.70151138305664, 'longitude': -79.43286895751953, 'postal_code': 'M5P2R5', 'property_id': '409d2421dde3d345', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '150 Old Forest Hill Road', 'bathroom_full': 2, 'bathroom_half': 0, 'bedroom': 6, 'city': 'Toronto', 'construction_year': 1978, 'den': 1, 'direction_facing': 'South', 'estimate_list_price': 879095, 'interior_sq_m': 104.58000183105469, 'latitude': 43.702110290527344, 'longitude': -79.4246826171875, 'postal_code': 'M5P2R5', 'property_id': '8b2a9b4ab2f79b12', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '2811 Dufferin Street', 'bathroom_full': 2, 'bathroom_half': 0, 'bedroom': 3, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 1336066, 'interior_sq_m': 104.58000183105469, 'latitude': 43.705440521240234, 'longitude': -79.45207977294922, 'postal_code': 'V0V0V0', 'property_id': '1afe2444031d8bdc', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '31 Symington Avenue', 'bathroom_full': 2, 'bathroom_half': 0, 'bedroom': 3, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 1193032, 'interior_sq_m': 104.58000183105469, 'latitude': 43.65834045410156, 'longitude': -79.44793701171875, 'postal_code': 'V0V0V0', 'property_id': '7058235d522380de', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '1050 Wilson Avenue', 'bathroom_full': 2, 'bathroom_half': 0, 'bedroom': 3, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 874292, 'interior_sq_m': 104.58000183105469, 'latitude': 43.72853088378906, 'longitude': -79.47943878173828, 'postal_code': 'V0V0V0', 'property_id': '2c59a9deea3531a9', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '137 Roxborough Street E', 'bathroom_full': 2, 'bathroom_half': 0, 'bedroom': 3, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 1874484, 'interior_sq_m': 104.58000183105469, 'latitude': 43.678958892822266, 'longitude': -79.38365173339844, 'postal_code': 'V0V0V0', 'property_id': '13df881c7940116f', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '37A Charles Street W', 'bathroom_full': 2, 'bathroom_half': 0, 'bedroom': 3, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 889454, 'interior_sq_m': 104.58000183105469, 'latitude': 43.668209075927734, 'longitude': -79.38768768310547, 'postal_code': 'V0V0V0', 'property_id': '1bc6222a1ee6b008', 'province': 'Ontario', 'score_bicycle': 9, 'score_educ ...

# %%
# Step 1: Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')

# Create the Database in Mongo Db
db = client['real_estate_project_db']  

# Create the collection in MongoDB
collection = db['property_listings_info'] 

input_json_path = os.path.join('Resources', 'data.json')
# Step 2: Load JSON data
with open(input_json_path, 'r') as file:
    file_data = json.load(file)

# Step 3: Insert data into the collection
# If file_data is a list of dictionaries
if isinstance(file_data, list):
    collection.insert_many(file_data)
else:
    collection.insert_one(file_data)

# Close the connection
client.close()

# %% [markdown]
# ## Toronto Schools Data

# %%
# Step 1: Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')

# Create the Database in Mongo Db
db = client['real_estate_project_db']  

# Create the collection in MongoDB
collection = db['schools_info'] 

input_json_path = os.path.join('Resources', 'toronto-schools.json')
# Step 2: Load JSON data
with open(input_json_path, 'r') as file:
    file_data = json.load(file)

# Step 3: Insert data into the collection
# If file_data is a list of dictionaries
if isinstance(file_data, list):
    collection.insert_many(file_data)
else:
    collection.insert_one(file_data)

# Close the connection
client.close()

# %%
# Connect to MongoDB client and list database names to identify the database to be exported to
mongo = MongoClient(port=27017)
print(mongo.list_database_names())
# Out:
# ['admin', 'ajunjee_db', 'autosaurus_db', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'mydb', 'petsitly_marketing', 'real_estate_project_db', 'uk_food']

# %%
# assign the database to a variable name
db = mongo['real_estate_project_db']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['property_listings_info', 'schools_info']

# %%
# review a document in the collection
print(db.schools_info.find_one())
# Out:
# {'_id': 2, 'OBJECTID': 2, 'GEO_ID': 524780, 'NAME': 'A R S ARMENIAN PRIVATE SCHOOL', 'SOURCE_ADDRESS': '50 HALLCROWN PL', 'SCHOOL_TYPE_DESC': 'Private', 'ADDRESS_POINT_ID': 524780, 'LINEAR_NAME_FULL': 'Hallcrown Pl', 'ADDRESS_FULL': '50 Hallcrown Pl', 'POSTAL_CODE': 'M2J 1P7', 'MUNICIPALITY': 'North York', 'CITY': 'Toronto', 'GENERAL_USE_CODE': 104008, 'LONG': -79.323156147744, 'LAT': 43.770053062482}

# %% [markdown]
# ## Subway Stations Data

# %%
# Set the column width
pd.options.display.max_colwidth = 200

# Read the dataset and store as pandas dataframe. 
stations = pd.read_excel("Resources/TTC Subway Stations.xlsx")
stations.head()
# Out:
#    ID            Station            Category                  Address  \
# 0   1              Finch  TTC Subway Station        5600 Yonge Street
# 1   2  North York Centre  TTC Subway Station        5102 Yonge Street
# 2   3     Sheppard–Yonge  TTC Subway Station  20 Sheppard Avenue West
# 3   4         York Mills  TTC Subway Station        4015 Yonge Street
# 4   5           Lawrence  TTC Subway Station        3101 Yonge Street
#
#          CITY Postal Code Line        Grade  Ridership (2019[9] avg. weekday)  \
# 0  North York     M2N 5S2    1  Underground                            102025
# 1  North York     M2N 6L8    1  Underground                             31471
# 2  North York     M2N 5M9  1,4  Underground                            134076
# 3  North York     M5M 3G1    1  Underground                             28461
# 4     Toronto     M4N 3N1    1  Underground                             28041
#
#   Parking spaces[10]  ... LAT min LAT seconds  LAT direction  LAT decimal  \
# 0          3,227[13]  ...      46        50.0              N    43.780556
# 1                  0  ...      46         6.0              N    43.768333
# 2                  0  ...      45        41.0              N    43.761389
# 3                  0  ...      44        39.0              N    43.744167
# 4                  0  ...      43        30.0              N    43.725000
#
#           LON LON degree  LON min LON seconds  LON direction  LON decimal
# 0  79°24?53?W         79       24        53.0              W    79.414722
# 1  79°24?46?W         79       24        46.0              W    79.412778
# 2  79°24?39?W         79       24        39.0              W    79.410833
# 3  79°24?24?W         79       24        24.0              W    79.406667
# 4   79°24?8?W         79       24         8.0              W    79.402222
#
# [5 rows x 23 columns]

# %%
# Rename columns
stations.rename(columns={'CITY': "City",
                            'Ridership (2019[9] avg. weekday)': "Ridership_Weekly_Average",
                            'Parking spaces[10]': "Parking_Spaces",
                            'Accessible[12]': "Accessibility",
                            'Postal Code': 'Postal_code',
                            'LAT': 'LAT coordinate',
                            'LON': 'LON coordinate',
                            'LAT decimal': "LAT",
                            'LON decimal': "LON"}, inplace=True)

# Update station name to include 'TTC Subway Station' so 'Category' column can be removed
stations['Station'] = stations['Station'] + ' TTC Subway Station'

# Create new column to include province
stations['Province'] = 'Ontario'

# %%
# Trim the reference info from the parking space count
stations['Parking_Spaces'] = stations['Parking_Spaces'].str[:-4]

# Remove comma from the parking space count to prepare for integer conversion
# Fill in the NAN columns with 0 values instead
# Convert parking space count to integer
stations['Parking_Spaces'] = stations['Parking_Spaces'].str.replace(",","").fillna(0).astype(int)

# Confrm columns have been cleaned and identify the necessary ones only for export to mongodb
stations.dtypes
# Out:
# ID                            int64
# Station                      object
# Category                     object
# Address                      object
# City                         object
# Postal_code                  object
# Line                         object
# Grade                        object
# Ridership_Weekly_Average      int64
# Parking_Spaces                int32
# Accessibility                object
# LAT coordinate               object
# LAT degree                    int64
# LAT min                       int64
# LAT seconds                 float64
# LAT direction                object
# LAT                         float64
# LON coordinate               object
# LON degree                    int64
# LON min                       int64
# LON seconds                 float64
# LON direction                object
# LON                         float64
# Province                     object
# dtype: object

# %%
# Update dataframe to include only the necessary columns for the MongoDB export
stations = stations[['Station','Address', 'City', 'Province', 'Postal_code','Line','Ridership_Weekly_Average', 'Parking_Spaces','Accessibility', 'LAT', 'LON']]

# Print to confirm data has been cleaned
stations.head()
# Out:
#                                 Station                  Address        City  \
# 0              Finch TTC Subway Station        5600 Yonge Street  North York
# 1  North York Centre TTC Subway Station        5102 Yonge Street  North York
# 2     Sheppard–Yonge TTC Subway Station  20 Sheppard Avenue West  North York
# 3         York Mills TTC Subway Station        4015 Yonge Street  North York
# 4           Lawrence TTC Subway Station        3101 Yonge Street     Toronto
#
#   Province Postal_code Line  Ridership_Weekly_Average  Parking_Spaces  \
# 0  Ontario     M2N 5S2    1                    102025            3227
# 1  Ontario     M2N 6L8    1                     31471               0
# 2  Ontario     M2N 5M9  1,4                    134076               0
# 3  Ontario     M5M 3G1    1                     28461               0
# 4  Ontario     M4N 3N1    1                     28041               0
#
#   Accessibility        LAT        LON
# 0           Yes  43.780556  79.414722
# 1           Yes  43.768333  79.412778
# 2           Yes  43.761389  79.410833
# 3           Yes  43.744167  79.406667
# 4            No  43.725000  79.402222

# %%
# Connect to MongoDB client and list database names to identify the database to be exported to
mongo = MongoClient(port=27017)
print(mongo.list_database_names())
# Out:
# ['admin', 'ajunjee_db', 'autosaurus_db', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'mydb', 'petsitly_marketing', 'real_estate_project_db', 'uk_food']

# %%
# Assign database to a variable
db = mongo['real_estate_project_db']
# List out the collections in the database
print(db.list_collection_names())
# Out:
# ['property_listings_info', 'schools_info']

# %%
# Assign the collection to a variable
ttc_subway = db['subway_stations_info']

# %%
# Convert the dataframe to dictionary values and insert all entries into the specified collection
stations.reset_index(inplace=True)
data_dict = stations.to_dict("records")
ttc_subway.insert_many(data_dict)
# Out:
# InsertManyResult([ObjectId('6621bf48207ddf030c83622b'), ObjectId('6621bf48207ddf030c83622c'), ObjectId('6621bf48207ddf030c83622d'), ObjectId('6621bf48207ddf030c83622e'), ObjectId('6621bf48207ddf030c83622f'), ObjectId('6621bf48207ddf030c836230'), ObjectId('6621bf48207ddf030c836231'), ObjectId('6621bf48207ddf030c836232'), ObjectId('6621bf48207ddf030c836233'), ObjectId('6621bf48207ddf030c836234'), ObjectId('6621bf48207ddf030c836235'), ObjectId('6621bf48207ddf030c836236'), ObjectId('6621bf48207ddf030c836237'), ObjectId('6621bf48207ddf030c836238'), ObjectId('6621bf48207ddf030c836239'), ObjectId('6621bf48207ddf030c83623a'), ObjectId('6621bf48207ddf030c83623b'), ObjectId('6621bf48207ddf030c83623c'), ObjectId('6621bf48207ddf030c83623d'), ObjectId('6621bf48207ddf030c83623e'), ObjectId('6621bf48207ddf030c83623f'), ObjectId('6621bf48207ddf030c836240'), ObjectId('6621bf48207ddf030c836241'), ObjectId('6621bf48207ddf030c836242'), ObjectId('6621bf48207ddf030c836243'), ObjectId('6621bf48207ddf030c836244'), ObjectId('6621bf48207ddf030c836245'), ObjectId('6621bf48207ddf030c836246'), ObjectId('6621bf48207ddf030c836247'), ObjectId('6621bf48207ddf030c836248'), ObjectId('6621bf48207ddf030c836249'), ObjectId('6621bf48207ddf030c83624a'), ObjectId('6621bf48207ddf030c83624b'), ObjectId('6621bf48207ddf030c83624c'), ObjectId('6621bf48207ddf030c83624d'), ObjectId('6621bf48207ddf030c83624e'), ObjectId('6621bf48207ddf030c83624f'), ObjectId('6621bf48207ddf030c836250'), ObjectId('6621bf48207ddf030c836251'), ObjectId('6621bf48207ddf030c836252'), ObjectId('6621bf48207ddf030c836253'), ObjectId('6621bf48207ddf030c836254'), ObjectId('6621bf48207ddf030c836255'), ObjectId('6621bf48207ddf030c836256'), ObjectId('6621bf48207ddf030c836257'), ObjectId('6621bf48207ddf030c836258'), ObjectId('6621bf48207ddf030c836259'), ObjectId('6621bf48207ddf030c83625a'), ObjectId('6621bf48207ddf030c83625b'), ObjectId('6621bf48207ddf030c83625c'), ObjectId('6621bf48207ddf030c83625d'), ObjectId('6621bf48207ddf030c83625e'), ObjectId('6621bf48207ddf030c83625f'), ObjectId('6621bf48207ddf030c836260'), ObjectId('6621bf48207ddf030c836261'), ObjectId('6621bf48207ddf030c836262'), ObjectId('6621bf48207ddf030c836263'), ObjectId('6621bf48207ddf030c836264'), ObjectId('6621bf48207ddf030c836265'), ObjectId('6621bf48207ddf030c836266'), ObjectId('6621bf48207ddf030c836267'), ObjectId('6621bf48207ddf030c836268'), ObjectId('6621bf48207ddf030c836269'), ObjectId('6621bf48207ddf030c83626a'), ObjectId('6621bf48207ddf030c83626b'), ObjectId('6621bf48207ddf030c83626c'), ObjectId('6621bf48207ddf030c83626d'), ObjectId('6621bf48207ddf030c83626e'), ObjectId('6621bf48207ddf030c83626f'), ObjectId('6621bf48207ddf030c836270')], acknowledged=True)

# %%
# List out the collections in the database
print(db.list_collection_names())
# Out:
# ['subway_stations_info', 'property_listings_info', 'schools_info']

# %%
# review a document in the collection
print(db.subway_stations_info.find_one())
# Out:
# {'_id': ObjectId('6621bf48207ddf030c83622b'), 'index': 0, 'Station': 'Finch TTC Subway Station', 'Address': '5600 Yonge Street', 'City': 'North York', 'Province': 'Ontario', 'Postal_code': 'M2N 5S2', 'Line': 1, 'Ridership_Weekly_Average': 102025, 'Parking_Spaces': 3227, 'Accessibility': 'Yes', 'LAT': 43.78055556, 'LON': 79.41472222}

# %% [markdown]
# ## Attractions Data

# %%
def clean_properties(properties):
    """
    Cleaning the properties dictionary by removing specified fields and renaming 'ADDRESS_FULL'.
    """
    # List of property names to remove from the dictionary
    remove_fields = [
        'EMAIL', 'GEOID', 'RECEIVED_DATE', 'ADDRESS_POINT_ID', 'ADDRESS_NUMBER',
        'LINEAR_NAME_FULL', 'PLACE_NAME', 'LO_NUM', 'LO_NUM_SUF', 'HI_NUM',
        'HI_NUM_SUF', 'LINEAR_NAME_ID', 'WARD_2003', 'WARD_2018', 'MI_PRINX',
        'MUNICIPALITY', 'GENERAL_USE_CODE', 'CENTRELINE', 'WARD', 'ATTRACTION', 
        'MAP_ACCESS', 'ADDRESS_INFO'
    ]

    # Renaming 'ADDRESS_FULL' to 'Address' 
    cleaned_properties = {'Address': properties.pop('ADDRESS_FULL', None)}
    # Flatten geometry data
    # cleaned_properties['Geometry Type'] = geometry['type']
    # cleaned_properties['Coordinates'] = json.dumps(geometry['coordinates'])

    # Use dictionary comprehension to remove unwanted fields and update with geometry info
    cleaned_properties.update({key: value for key, value in properties.items() if key not in remove_fields})
    
    return cleaned_properties

# %%
def clean_geojson(geojson_data):
    """
    Iterating over all features in the GEOJSON data, cleaning properties and including geometry.
    """
    cleaned_features = []
    for feature in geojson_data['features']:
        # Clean properties of each feature
        feature['properties'] = clean_properties(feature['properties'])
        # Collect the cleaned features (currently commented out)
        # cleaned_features.append(cleaned_feature)

    # Replace original features with cleaned features (currently commented out)
    # geojson_data['features'] = cleaned_features
    return geojson_data

# %%
def export_to_csv(data, output_csv_path):
    """
    Exporting cleaned geojson data to a CSV file, including geometry information.
    """
    with open(output_csv_path, mode='w', newline='', encoding='utf-8') as csv_file:
        # Checking if there are features to export
        if data['features']:
            #Define the headers for the CSV file
            fieldnames = ['Address', 'Geometry Type', 'Coordinates']  # Add Geometry headers
            # Adding other property names as headers, excluding geometry fields for simplicity
            fieldnames += [key for key in data['features'][0]['properties'].keys() if key not in ('Address', 'Geometry Type', 'Coordinates')]
            writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
            writer.writeheader()
            # Writing each feature's properties to the CSV
            for feature in data['features']:
                writer.writerow(feature['properties'])

# %%
def print_json(data):
    """
    Print the JSON content of the cleaned data, including geometry information.
    """
    print(json.dumps(data, indent=4))

# %%
# Defining file paths
file_path = os.path.join('Resources', 'Attractions.geojson')
output_csv_path = os.path.join('Resources', 'Cleaned_Attractions.csv')
output_json_path = os.path.join('Resources', 'Cleaned_Attractions.json')

try:
    with open(file_path, 'r') as file:
        geojson_data = json.load(file)
        
    # Cleaning the GEOJSON data
    cleaned_geojson_data = clean_geojson(geojson_data)

    # Export to CSV
    export_to_csv(cleaned_geojson_data, output_csv_path)
    print(f"Data has been exported to CSV at {output_csv_path}")

    # Export to JSON
    with open(output_json_path, 'w') as file:
        json.dump(cleaned_geojson_data, file, indent=4)
    print(f"Data has been exported to JSON at {output_json_path}")

except FileNotFoundError:
    print(f"The file {file_path} does not exist.")
except json.JSONDecodeError:
    print("Error decoding JSON from the file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data has been exported to CSV at Resources\Cleaned_Attractions.csv
# Data has been exported to JSON at Resources\Cleaned_Attractions.json

# %%
# MongoDB connection parameters
host = 'localhost'  # The server address where MongoDB is running
port = 27017         # The port on which MongoDB listens
dbname = 'real_estate_project_db' # The name of the database to connect to
collection_name = 'attractions_info'  # The name of the collection to insert data into

# Path to the cleaned JSON file
input_json_path = os.path.join('Resources', 'Cleaned_Attractions.json')

# Connect to MongoDB
client = MongoClient(host, port)  # Create a MongoDB client
db = client[dbname]               # Select the database
collection = db[collection_name]  # Select the collection

# Loading the cleaned JSON data
with open(input_json_path, 'r') as file:  # Opening the JSON file for reading
    data = json.load(file)  # Loading JSON data from file
    # Extracting 'features' from data assuming it is structured for GeoJSON
    features = data.get('features', [])
    documents = [feature for feature in features]

# Inserting documents into the collection
collection.insert_many(documents) # Inserting all documents into the MongoDB collection
print(f"Data has been imported to MongoDB collection '{collection_name}' in database '{dbname}'.")

# Closing the connection to MongoDB
client.close()
# Out:
# Data has been imported to MongoDB collection 'attractions_info' in database 'real_estate_project_db'.

# %%
# List out the collections in the database
mongo = MongoClient(port=27017)
db = mongo['real_estate_project_db']  
print(db.list_collection_names())
# Out:
# ['subway_stations_info', 'attractions_info', 'property_listings_info', 'schools_info']

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
