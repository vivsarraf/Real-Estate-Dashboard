# %%
# Import dependencies
import requests
import pprint
import pandas as pd
import json
import os
import csv
from pymongo import MongoClient
from pprint import pprint

# %% [markdown]
# ## Property Listings Data

# %%
# Parameters for getting all the Property data from Houski Api
params = {}
params['api_key'] = '698c8c20-7e89-4f9b-a8c0-ac7fd9d76313'
params['city'] = 'toronto'
params['country_abbreviation'] = 'ca'
params['province_abbreviation'] = 'on'
params['results_per_page'] = '370'
params['select'] = 'address,latitude,longitude,city,province,postal_code,direction_facing,den,list_price,estimate_list_price,property_taxes,land_area_sq_m,interior_sq_m,bedroom,bathroom_full,bathroom_half,construction_year,property_taxes,score_education,score_food_and_drink,score_bicycle,score_entertainment,score_safety,score_shopping,score_traffic,score_transit,score_walkability'

# Make the API request
response = requests.get('https://api.houski.ca/properties', params=params)

# Extract the json result
if response.status_code == 200:
    json_data = response.json()
    pprint(json_data)
else:
    print(f'Failed to get data: {response}')
# Out:
# {'cache_hit': False,
#  'cost_cents': 965.6998901367188,
#  'data': [{'address': '30 Lambton Avenue Upper',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 969205,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.68386459350586,
#            'longitude': -79.4864730834961,
#            'postal_code': 'V0V0V0',
#            'property_id': '505d8aa297d16c6b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '263 Dixon Roadd',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 459754,
#            'interior_sq_m': 65.0321273803711,
#            'latitude': 43.69526672363281,
#            'longitude': -79.54774475097656,
#            'postal_code': 'V0V0V0',
#            'property_id': '67c3790f65e2bbf4',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '22 Rusholme Park Crescent Main',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 461047,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.65227508544922,
#            'longitude': -79.42887878417969,
#            'postal_code': 'V0V0V0',
#            'property_id': 'd070b024a4cf9959',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '7895 Jane Street',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 933905,
#            'interior_sq_m': 116.12879943847656,
#            'latitude': 43.79847717285156,
#            'longitude': -79.52503967285156,
#            'postal_code': 'V0V0V0',
#            'property_id': 'c7307e188972d3a0',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2 Moraine Hill Drive Main',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 664296,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.77464294433594,
#            'longitude': -79.29815673828125,
#            'postal_code': 'V0V0V0',
#            'property_id': '464211196a182bb8',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '699 Eglinton Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 508426,
#            'interior_sq_m': 58.06439971923828,
#            'latitude': 43.70185470581055,
#            'longitude': -79.42024230957031,
#            'postal_code': 'V0V0V0',
#            'property_id': '431224f04ffabc44',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '10 10 Laidlaw Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 474479,
#            'interior_sq_m': 46.45151901245117,
#            'latitude': 43.6397819519043,
#            'longitude': -79.42665100097656,
#            'postal_code': 'V0V0V0',
#            'property_id': 'a2a87b85d84498fa',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '560 Bathurst Street Bsmt',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 630106,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.658565521240234,
#            'longitude': -79.4087905883789,
#            'postal_code': 'V0V0V0',
#            'property_id': '5e39d7c6fb5c35f2',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '115 Eglinton Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 612153,
#            'interior_sq_m': 60.3869743347168,
#            'latitude': 43.70568084716797,
#            'longitude': -79.40211486816406,
#            'postal_code': 'V0V0V0',
#            'property_id': '9cf4cc1138f39029',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '915 Street Clair Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 567056,
#            'interior_sq_m': 52.211509704589844,
#            'latitude': 43.67966079711914,
#            'longitude': -79.43392944335938,
#            'postal_code': 'V0V0V0',
#            'property_id': 'e290669c442c55d7',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2 Moraine Hill Drive Lower',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 979272,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.77464294433594,
#            'longitude': -79.29815673828125,
#            'postal_code': 'V0V0V0',
#            'property_id': 'b67fa62ca16ced63',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '82 Livingston Avenue',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 996021,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.69831466674805,
#            'longitude': -79.44276428222656,
#            'postal_code': 'V0V0V0',
#            'property_id': '416248aa9dcfe51b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1001 Cosburn Avenue Bsmt',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 647860,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.697174072265625,
#            'longitude': -79.31060028076172,
#            'postal_code': 'V0V0V0',
#            'property_id': '6d334c3eb134e984',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '187 Rathburn Road Road E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1490100,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.6580924987793,
#            'longitude': -79.54960632324219,
#            'postal_code': 'V0V0V0',
#            'property_id': '71d46b72ff8ab757',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '917 Street Clair Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 609890,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.67962646484375,
#            'longitude': -79.43412780761719,
#            'postal_code': 'V0V0V0',
#            'property_id': '9ecce1d8368c6ee0',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '82 Livingstone Avenue Upper',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 996021,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.69831466674805,
#            'longitude': -79.44276428222656,
#            'postal_code': 'V0V0V0',
#            'property_id': '178e483c7b6a33d6',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '32 Shouldice',
#            'bathroom_full': 2,
#            'bathroom_half': 1,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1397704,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.76335144042969,
#            'longitude': -79.3672103881836,
#            'postal_code': 'V0V0V0',
#            'property_id': '5eb446a0dbd9a476',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '30 Lambton Avenue Main',
#            'bathroom_full': 2,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1010118,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.68386459350586,
#            'longitude': -79.4864730834961,
#            'postal_code': 'V0V0V0',
#            'property_id': 'a8b70dbd3be67b8b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1120 Briar Hill Avenue C305',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 830402,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.70322799682617,
#            'longitude': -79.4512710571289,
#            'postal_code': 'V0V0V0',
#            'property_id': '1eac1a8cee28387c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '551 Eglinton Avenue East',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 679117,
#            'interior_sq_m': 82.4979019165039,
#            'latitude': 43.710445404052734,
#            'longitude': -79.37863159179688,
#            'postal_code': 'V0V0V0',
#            'property_id': '795018d847499fcd',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2724 Lakeshore West',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 790400,
#            'interior_sq_m': 119.28750610351562,
#            'latitude': 43.603668212890625,
#            'longitude': -79.49807739257812,
#            'postal_code': 'V0V0V0',
#            'property_id': '38ff3c5f4f8e58bb',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '771 Indian Road Main',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 534876,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.66309356689453,
#            'longitude': -79.45870971679688,
#            'postal_code': 'V0V0V0',
#            'property_id': '96ac05b538064731',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '260 Queens Quay West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 548118,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.6393928527832,
#            'longitude': -79.38575744628906,
#            'postal_code': 'M5V3M3',
#            'property_id': 'cf96a2504fe60838',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '110 110 Maria Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 672081,
#            'interior_sq_m': 148.64486694335938,
#            'latitude': 43.66672897338867,
#            'longitude': -79.47660827636719,
#            'postal_code': 'V0V0V0',
#            'property_id': 'd92e7f8ec6111695',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '205 Danforth Avenue 2 Fl',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 529650,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.676631927490234,
#            'longitude': -79.3559799194336,
#            'postal_code': 'V0V0V0',
#            'property_id': 'ee017f98d4a06c89',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '61 Clouston Avenue Lower',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 621293,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.6943244934082,
#            'longitude': -79.5072250366211,
#            'postal_code': 'V0V0V0',
#            'property_id': 'ca371fa3038141c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3541 Danforth Road',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 918827,
#            'interior_sq_m': 68.65534973144531,
#            'latitude': 43.69501495361328,
#            'longitude': -79.27589416503906,
#            'postal_code': 'M1J0A9',
#            'property_id': '5b098b745858fdce',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '22624 Eglinton Avenue East',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 524304,
#            'interior_sq_m': 74.32243347167969,
#            'latitude': 43.736419677734375,
#            'longitude': -79.25174713134766,
#            'postal_code': 'V0V0V0',
#            'property_id': '7a8aeecbc47a6dcb',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '82 Livingstone Avenue Main',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 996021,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.69831466674805,
#            'longitude': -79.44276428222656,
#            'postal_code': 'V0V0V0',
#            'property_id': 'dfd3433dbdb653dd',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '697 Eglinton Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 581458,
#            'interior_sq_m': 90.85917663574219,
#            'latitude': 43.70195007324219,
#            'longitude': -79.4200210571289,
#            'postal_code': 'V0V0V0',
#            'property_id': 'e92ddd237ca39c5d',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '800 Richmond Street West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 811022,
#            'interior_sq_m': 21.92511749267578,
#            'latitude': 43.644981384277344,
#            'longitude': -79.40995025634766,
#            'postal_code': 'V0V0V0',
#            'property_id': '756d21884ee11472',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '220 Ellington Drive Main',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 659058,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.75785446166992,
#            'longitude': -79.2954330444336,
#            'postal_code': 'V0V0V0',
#            'property_id': 'fc43dd789d879089',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '150 The Donway West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 510636,
#            'interior_sq_m': 82.31209564208984,
#            'latitude': 43.73347473144531,
#            'longitude': -79.3475112915039,
#            'postal_code': 'M3C0N8',
#            'property_id': 'd9d9af7de3bacd0a',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '365 Eglinton Avenue East',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 685354,
#            'interior_sq_m': 64.10309600830078,
#            'latitude': 43.70909118652344,
#            'longitude': -79.38549041748047,
#            'postal_code': 'V0V0V0',
#            'property_id': 'b40d4b03d2b2360d',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1194 Royal York Road Bsmt',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 516627,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.66469192504883,
#            'longitude': -79.5194320678711,
#            'postal_code': 'V0V0V0',
#            'property_id': 'd2e922990666b904',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3008 Queen Street East',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 698100,
#            'interior_sq_m': 68.84115600585938,
#            'latitude': 43.67543411254883,
#            'longitude': -79.27739715576172,
#            'postal_code': 'V0V0V0',
#            'property_id': 'b3d989bd2705ecd8',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '493 Clarens Avenue',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 479926,
#            'interior_sq_m': 55.741825103759766,
#            'latitude': 43.659912109375,
#            'longitude': -79.44204711914062,
#            'postal_code': 'V0V0V0',
#            'property_id': 'f6c5b7ba499dcb38',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '701 Eglinton Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 590282,
#            'interior_sq_m': 72.83598327636719,
#            'latitude': 43.701820373535156,
#            'longitude': -79.42054748535156,
#            'postal_code': 'V0V0V0',
#            'property_id': '825d4687008d1521',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '115 Livingstone Avenue Lower',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 940621,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.69765853881836,
#            'longitude': -79.44416809082031,
#            'postal_code': 'V0V0V0',
#            'property_id': '1b35245e07350dde',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '105 785 Browns Line',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 469007,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.6087646484375,
#            'longitude': -79.54756927490234,
#            'postal_code': 'M8W3V8',
#            'property_id': 'ca1b67665e671468',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1009 150 East Liberty Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 737744,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.638763427734375,
#            'longitude': -79.41624450683594,
#            'postal_code': 'M6K3R5',
#            'property_id': 'c430e98fb0dc71b6',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1607 100 Hayden Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 788929,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.670589447021484,
#            'longitude': -79.38164520263672,
#            'postal_code': 'M4Y3C7',
#            'property_id': '94af647a80232241',
#            'property_taxes': 2971,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '204 5155 Sheppard Avenue E',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 580809,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.79403305053711,
#            'longitude': -79.23654174804688,
#            'postal_code': 'M1B0C8',
#            'property_id': '3278ce0dc7b1c511',
#            'property_taxes': 1858,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': 'Ph407 5765 Yonge Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 724103,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.783119201660156,
#            'longitude': -79.41486358642578,
#            'postal_code': 'M2M4H9',
#            'property_id': 'e40b520b7058b99',
#            'property_taxes': 2300,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2604 16 Brookers Lane',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 834571,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.62691116333008,
#            'longitude': -79.4786148071289,
#            'postal_code': 'M8V0A5',
#            'property_id': 'ec47ca00acff65d4',
#            'property_taxes': 2676,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3209 33 Charles Street E',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 760078,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.6685791015625,
#            'longitude': -79.38447570800781,
#            'postal_code': 'M4Y0A2',
#            'property_id': 'd44ef1a1fcc4c455',
#            'property_taxes': 3153,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '303 25 Adra Grado Way',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 718801,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.77647399902344,
#            'longitude': -79.36602783203125,
#            'postal_code': 'M2J2A8',
#            'property_id': '86d4e371b421bff',
#            'property_taxes': 2454,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '809 50 Ordnance Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 654946,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.63970184326172,
#            'longitude': -79.40972137451172,
#            'postal_code': 'M6K0C9',
#            'property_id': '137c31d72c749312',
#            'property_taxes': 2465,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1101 25 Scrivener Square',
#            'bathroom_full': 3,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 3613921,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.68073272705078,
#            'longitude': -79.38922882080078,
#            'postal_code': 'M4W3Y6',
#            'property_id': '62e8b7b46f3009a9',
#            'property_taxes': 20281,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1910 386 Yonge Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1274343,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.65925216674805,
#            'longitude': -79.38273620605469,
#            'postal_code': 'M5B0A5',
#            'property_id': '8d5531d79317e73',
#            'property_taxes': 5630,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '417 70 Town Center Court',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 0,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 402137,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.773712158203125,
#            'longitude': -79.25545501708984,
#            'postal_code': 'M1P0B2',
#            'property_id': '63c2796f331379f',
#            'property_taxes': 979,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '503 801 Sheppard Avenue W',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 519690,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.75297546386719,
#            'longitude': -79.44944763183594,
#            'postal_code': 'M3H2T3',
#            'property_id': 'c2343c456a90fd5c',
#            'property_taxes': 1705,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1710 21 Iceboat Terrace',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 551176,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.640499114990234,
#            'longitude': -79.39743041992188,
#            'postal_code': 'M5V4A9',
#            'property_id': 'fc322ee7f27b7b14',
#            'property_taxes': 2112,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '810 30 Samuel Wood Way',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 583427,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.63468933105469,
#            'longitude': -79.54055786132812,
#            'postal_code': 'M9B0C9',
#            'property_id': 'df4b7d083982def1',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1401 33 Helendale Avenue',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 697082,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.65322494506836,
#            'longitude': -79.38318634033203,
#            'postal_code': 'M4R0A4',
#            'property_id': '4cb5ddd0b2f13cea',
#            'property_taxes': 2811,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3402 159 Wellesley Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
# ...
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '100304 20 Avoca Avenue',
#            'bathroom_full': 4,
#            'bathroom_half': 0,
#            'bedroom': 5,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 2666281,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.688053131103516,
#            'longitude': -79.38915252685547,
#            'postal_code': 'M4T2B7',
#            'property_id': '5f3344175b2d682c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '311 293 The Kingsway',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 630441,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.663352966308594,
#            'longitude': -79.52033996582031,
#            'postal_code': 'M9A3T9',
#            'property_id': '231c43596de4d942',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2201 197 Yonge Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 653030,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.65343475341797,
#            'longitude': -79.37918853759766,
#            'postal_code': 'M5B0C1',
#            'property_id': 'c3586c60837375ad',
#            'property_taxes': 2401,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '614 65 East Liberty Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 508555,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.638519287109375,
#            'longitude': -79.41421508789062,
#            'postal_code': 'M6K3R2',
#            'property_id': '904a7341f6256850',
#            'property_taxes': 1585,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '202 15 Legion Road',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 578839,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.621368408203125,
#            'longitude': -79.4840316772461,
#            'postal_code': 'M8V0A9',
#            'property_id': 'd20711409fe72216',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '315 231 Fort York Boulevard',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 655748,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.63703918457031,
#            'longitude': -79.4063949584961,
#            'postal_code': 'M5V1B2',
#            'property_id': '78ec7460ad092176',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1609 36 Lee Center Drive',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 596921,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.78183364868164,
#            'longitude': -79.24685668945312,
#            'postal_code': 'M1H3K2',
#            'property_id': '102c9f9be371bb27',
#            'property_taxes': 1845,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '749 5 Hanna Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 748119,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.63759231567383,
#            'longitude': -79.41871643066406,
#            'postal_code': 'M6K0B3',
#            'property_id': 'da4ab3e340e6b057',
#            'property_taxes': 2880,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '17 Kenscott Road N',
#            'bathroom_full': 4,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 2,
#            'direction_facing': 'South',
#            'estimate_list_price': 1462269,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.802669525146484,
#            'longitude': -79.17488861083984,
#            'postal_code': 'M1B2L8',
#            'property_id': '56cd758e69606b8d',
#            'property_taxes': 3366,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '416 100 Dalhousie Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 752627,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.65662384033203,
#            'longitude': -79.37653350830078,
#            'postal_code': 'M5B1E1',
#            'property_id': 'f98383be4d388c9b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1022 Pauline Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1305911,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.65949630737305,
#            'longitude': -79.43810272216797,
#            'postal_code': 'M6H3M8',
#            'property_id': '9a68846954262af8',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': 'Lph12 608 Richmond Street W',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 695779,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.64682388305664,
#            'longitude': -79.40291595458984,
#            'postal_code': 'M5V1Y9',
#            'property_id': '48e86c5a1285132a',
#            'property_taxes': 3071,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '609 75 Dalhousie Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 591707,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.65572738647461,
#            'longitude': -79.37590026855469,
#            'postal_code': 'M5B2R9',
#            'property_id': 'afb4b849ef0270cc',
#            'property_taxes': 2121,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '732 460 Adelaide Street E',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 569847,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.652679443359375,
#            'longitude': -79.3667984008789,
#            'postal_code': 'M5A0E7',
#            'property_id': 'eb9c79154280c739',
#            'property_taxes': 2154,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2001 20 Bruyeres Mews',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 623919,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.63750076293945,
#            'longitude': -79.40103912353516,
#            'postal_code': 'M5V0G8',
#            'property_id': '4b57a10aff2441fb',
#            'property_taxes': 1925,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1511 18 Holmes Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 664955,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.77848434448242,
#            'longitude': -79.413330078125,
#            'postal_code': 'M2N0E1',
#            'property_id': '7815c2db8a2b5231',
#            'property_taxes': 2445,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1616 7 King Street E',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 640405,
#            'interior_sq_m': 104.5050048828125,
#            'latitude': 43.64925003051758,
#            'longitude': -79.37703704833984,
#            'postal_code': 'M5C3C5',
#            'property_id': '403c2a856cbd5f45',
#            'property_taxes': 2415,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9}],
#  'error': '',
#  'pagination': {'current_page': 1,
#                 'has_next_page': True,
#                 'has_previous_page': False,
#                 'page_total': 1508},
#  'price_quote': False,
#  'result_total': 557816,
#  'time_ms': 184,
#  'ui_info': {'city': 'Toronto',
#              'city_id': '6cdbdee2492718ed',
#              'city_link': 'ca/on/toronto',
#              'city_slug': 'toronto',
#              'country': 'Canada',
#              'country_abbreviation': 'CA',
#              'country_abbreviation_id': '9ace2b6431b7f1be',
#              'country_abbreviation_link': 'ca',
#              'country_slug': 'canada',
#              'province': 'Ontario',
#              'province_abbreviation': 'ON',
#              'province_abbreviation_id': '146699ee774499d3',
#              'province_abbreviation_link': 'ca/on',
#              'province_slug': 'ontario'}}

# %%
# Extract the data from Json
Property_data=json_data["data"]
print(Property_data)
# Out:
# [{'address': '30 Lambton Avenue Upper', 'bathroom_full': 1, 'bathroom_half': 1, 'bedroom': 3, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 969205, 'interior_sq_m': 104.5050048828125, 'latitude': 43.68386459350586, 'longitude': -79.4864730834961, 'postal_code': 'V0V0V0', 'property_id': '505d8aa297d16c6b', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '263 Dixon Roadd', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 1, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 459754, 'interior_sq_m': 65.0321273803711, 'latitude': 43.69526672363281, 'longitude': -79.54774475097656, 'postal_code': 'V0V0V0', 'property_id': '67c3790f65e2bbf4', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '22 Rusholme Park Crescent Main', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 1, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 461047, 'interior_sq_m': 104.5050048828125, 'latitude': 43.65227508544922, 'longitude': -79.42887878417969, 'postal_code': 'V0V0V0', 'property_id': 'd070b024a4cf9959', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '7895 Jane Street', 'bathroom_full': 1, 'bathroom_half': 1, 'bedroom': 3, 'city': 'Toronto', 'construction_year': 1978, 'den': 1, 'direction_facing': 'South', 'estimate_list_price': 933905, 'interior_sq_m': 116.12879943847656, 'latitude': 43.79847717285156, 'longitude': -79.52503967285156, 'postal_code': 'V0V0V0', 'property_id': 'c7307e188972d3a0', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '2 Moraine Hill Drive Main', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 3, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 664296, 'interior_sq_m': 104.5050048828125, 'latitude': 43.77464294433594, 'longitude': -79.29815673828125, 'postal_code': 'V0V0V0', 'property_id': '464211196a182bb8', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '699 Eglinton Avenue West', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 1, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 508426, 'interior_sq_m': 58.06439971923828, 'latitude': 43.70185470581055, 'longitude': -79.42024230957031, 'postal_code': 'V0V0V0', 'property_id': '431224f04ffabc44', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '10 10 Laidlaw Street', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 1, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 474479, 'interior_sq_m': 46.45151901245117, 'latitude': 43.6397819519043, 'longitude': -79.42665100097656, 'postal_code': 'V0V0V0', 'property_id': 'a2a87b85d84498fa', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, ...

# %%
# Step 1: Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')

# Create the Database in Mongo Db
db = client['real_estate_project_db']  

# Create the collection in MongoDB
collection = db['property_listings_info'] 

input_json_path = os.path.join('Data', 'data.json')
# Step 2: Load JSON data
with open(input_json_path, 'r') as file:
    file_data = json.load(file)

# Step 3: Insert data into the collection
# If file_data is a list of dictionaries
if isinstance(file_data, list):
    collection.insert_many(file_data)
else:
    collection.insert_one(file_data)

# Close the connection
client.close()

# %% [markdown]
# ## Toronto Schools Data

# %%
# Step 1: Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')

# Create the Database in Mongo Db
db = client['real_estate_project_db']  

# Create the collection in MongoDB
collection = db['schools_info'] 

input_json_path = os.path.join('Data', 'toronto-schools.json')
# Step 2: Load JSON data
with open(input_json_path, 'r') as file:
    file_data = json.load(file)

# Step 3: Insert data into the collection
# If file_data is a list of dictionaries
if isinstance(file_data, list):
    collection.insert_many(file_data)
else:
    collection.insert_one(file_data)

# Close the connection
client.close()

# %%
# Connect to MongoDB client and list database names to identify the database to be exported to
mongo = MongoClient(port=27017)
print(mongo.list_database_names())
# Out:
# ['admin', 'ajunjee_db', 'autosaurus_db', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'mydb', 'petsitly_marketing', 'real_estate_project_db', 'uk_food']

# %%
# assign the database to a variable name
db = mongo['real_estate_project_db']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['property_listings_info', 'schools_info']

# %%
# review a document in the collection
print(db.schools_info.find_one())
# Out:
# {'_id': 2, 'OBJECTID': 2, 'GEO_ID': 524780, 'NAME': 'A R S ARMENIAN PRIVATE SCHOOL', 'SOURCE_ADDRESS': '50 HALLCROWN PL', 'SCHOOL_TYPE_DESC': 'Private', 'ADDRESS_POINT_ID': 524780, 'LINEAR_NAME_FULL': 'Hallcrown Pl', 'ADDRESS_FULL': '50 Hallcrown Pl', 'POSTAL_CODE': 'M2J 1P7', 'MUNICIPALITY': 'North York', 'CITY': 'Toronto', 'GENERAL_USE_CODE': 104008, 'LONG': -79.323156147744, 'LAT': 43.770053062482}

# %% [markdown]
# ## Subway Stations Data

# %%
# Set the column width
pd.options.display.max_colwidth = 200

# Read the dataset and store as pandas dataframe. 
stations = pd.read_excel("Data/TTC Subway Stations.xlsx")
stations.head()
# Out:
#    ID            Station            Category                  Address  \
# 0   1              Finch  TTC Subway Station        5600 Yonge Street
# 1   2  North York Centre  TTC Subway Station        5102 Yonge Street
# 2   3     Sheppard–Yonge  TTC Subway Station  20 Sheppard Avenue West
# 3   4         York Mills  TTC Subway Station        4015 Yonge Street
# 4   5           Lawrence  TTC Subway Station        3101 Yonge Street
#
#          CITY Postal Code Line        Grade  Ridership (2019[9] avg. weekday)  \
# 0  North York     M2N 5S2    1  Underground                            102025
# 1  North York     M2N 6L8    1  Underground                             31471
# 2  North York     M2N 5M9  1,4  Underground                            134076
# 3  North York     M5M 3G1    1  Underground                             28461
# 4     Toronto     M4N 3N1    1  Underground                             28041
#
#   Parking spaces[10]  ... LAT min LAT seconds  LAT direction  LAT decimal  \
# 0          3,227[13]  ...      46        50.0              N    43.780556
# 1                  0  ...      46         6.0              N    43.768333
# 2                  0  ...      45        41.0              N    43.761389
# 3                  0  ...      44        39.0              N    43.744167
# 4                  0  ...      43        30.0              N    43.725000
#
#           LON LON degree  LON min LON seconds  LON direction  LON decimal
# 0  79°24?53?W         79       24        53.0              W   -79.414722
# 1  79°24?46?W         79       24        46.0              W   -79.412778
# 2  79°24?39?W         79       24        39.0              W   -79.410833
# 3  79°24?24?W         79       24        24.0              W   -79.406667
# 4   79°24?8?W         79       24         8.0              W   -79.402222
#
# [5 rows x 23 columns]

# %%
# Rename columns
stations.rename(columns={'CITY': "City",
                            'Ridership (2019[9] avg. weekday)': "Ridership_Weekly_Average",
                            'Parking spaces[10]': "Parking_Spaces",
                            'Accessible[12]': "Accessibility",
                            'Postal Code': 'Postal_code',
                            'LAT': 'LAT coordinate',
                            'LON': 'LON coordinate',
                            'LAT decimal': "LAT",
                            'LON decimal': "LON"}, inplace=True)

# Update station name to include 'TTC Subway Station' so 'Category' column can be removed
stations['Station'] = stations['Station'] + ' TTC Subway Station'

# Create new column to include province
stations['Province'] = 'Ontario'

# %%
stations['Coordinates'] = list(zip(stations['LAT'], stations['LON']))

# %%
# Trim the reference info from the parking space count
stations['Parking_Spaces'] = stations['Parking_Spaces'].str[:-4]

# Remove comma from the parking space count to prepare for integer conversion
# Fill in the NAN columns with 0 values instead
# Convert parking space count to integer
stations['Parking_Spaces'] = stations['Parking_Spaces'].str.replace(",","").fillna(0).astype(int)

# Confrm columns have been cleaned and identify the necessary ones only for export to mongodb
stations.dtypes
# Out:
# ID                            int64
# Station                      object
# Category                     object
# Address                      object
# City                         object
# Postal_code                  object
# Line                         object
# Grade                        object
# Ridership_Weekly_Average      int64
# Parking_Spaces                int32
# Accessibility                object
# LAT coordinate               object
# LAT degree                    int64
# LAT min                       int64
# LAT seconds                 float64
# LAT direction                object
# LAT                         float64
# LON coordinate               object
# LON degree                    int64
# LON min                       int64
# LON seconds                 float64
# LON direction                object
# LON                         float64
# Province                     object
# Coordinates                  object
# dtype: object

# %%
# Update dataframe to include only the necessary columns for the MongoDB export
stations = stations[['Station','Address', 'City', 'Province', 'Postal_code','Line','Ridership_Weekly_Average', 'Parking_Spaces','Accessibility', 'LAT', 'LON', 'Coordinates']]

# Print to confirm data has been cleaned
stations.head()
# Out:
#                                 Station                  Address        City  \
# 0              Finch TTC Subway Station        5600 Yonge Street  North York
# 1  North York Centre TTC Subway Station        5102 Yonge Street  North York
# 2     Sheppard–Yonge TTC Subway Station  20 Sheppard Avenue West  North York
# 3         York Mills TTC Subway Station        4015 Yonge Street  North York
# 4           Lawrence TTC Subway Station        3101 Yonge Street     Toronto
#
#   Province Postal_code Line  Ridership_Weekly_Average  Parking_Spaces  \
# 0  Ontario     M2N 5S2    1                    102025            3227
# 1  Ontario     M2N 6L8    1                     31471               0
# 2  Ontario     M2N 5M9  1,4                    134076               0
# 3  Ontario     M5M 3G1    1                     28461               0
# 4  Ontario     M4N 3N1    1                     28041               0
#
#   Accessibility        LAT        LON                  Coordinates
# 0           Yes  43.780556 -79.414722  (43.78055556, -79.41472222)
# 1           Yes  43.768333 -79.412778  (43.76833333, -79.41277778)
# 2           Yes  43.761389 -79.410833  (43.76138889, -79.41083333)
# 3           Yes  43.744167 -79.406667  (43.74416667, -79.40666667)
# 4            No  43.725000 -79.402222       (43.725, -79.40222222)

# %%
# Connect to MongoDB client and list database names to identify the database to be exported to
mongo = MongoClient(port=27017)
print(mongo.list_database_names())
# Out:
# ['admin', 'ajunjee_db', 'autosaurus_db', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'mydb', 'petsitly_marketing', 'real_estate_project_db', 'uk_food']

# %%
# Assign database to a variable
db = mongo['real_estate_project_db']
# List out the collections in the database
print(db.list_collection_names())
# Out:
# ['property_listings_info', 'schools_info']

# %%
# Assign the collection to a variable
ttc_subway = db['subway_stations_info']

# %%
# Convert the dataframe to dictionary values and insert all entries into the specified collection
stations.reset_index(inplace=True)
data_dict = stations.to_dict("records")
ttc_subway.insert_many(data_dict)
# Out:
# InsertManyResult([ObjectId('6626f478af532d5b3c52f9bb'), ObjectId('6626f478af532d5b3c52f9bc'), ObjectId('6626f478af532d5b3c52f9bd'), ObjectId('6626f478af532d5b3c52f9be'), ObjectId('6626f478af532d5b3c52f9bf'), ObjectId('6626f478af532d5b3c52f9c0'), ObjectId('6626f478af532d5b3c52f9c1'), ObjectId('6626f478af532d5b3c52f9c2'), ObjectId('6626f478af532d5b3c52f9c3'), ObjectId('6626f478af532d5b3c52f9c4'), ObjectId('6626f478af532d5b3c52f9c5'), ObjectId('6626f478af532d5b3c52f9c6'), ObjectId('6626f478af532d5b3c52f9c7'), ObjectId('6626f478af532d5b3c52f9c8'), ObjectId('6626f478af532d5b3c52f9c9'), ObjectId('6626f478af532d5b3c52f9ca'), ObjectId('6626f478af532d5b3c52f9cb'), ObjectId('6626f478af532d5b3c52f9cc'), ObjectId('6626f478af532d5b3c52f9cd'), ObjectId('6626f478af532d5b3c52f9ce'), ObjectId('6626f478af532d5b3c52f9cf'), ObjectId('6626f478af532d5b3c52f9d0'), ObjectId('6626f478af532d5b3c52f9d1'), ObjectId('6626f478af532d5b3c52f9d2'), ObjectId('6626f478af532d5b3c52f9d3'), ObjectId('6626f478af532d5b3c52f9d4'), ObjectId('6626f478af532d5b3c52f9d5'), ObjectId('6626f478af532d5b3c52f9d6'), ObjectId('6626f478af532d5b3c52f9d7'), ObjectId('6626f478af532d5b3c52f9d8'), ObjectId('6626f478af532d5b3c52f9d9'), ObjectId('6626f478af532d5b3c52f9da'), ObjectId('6626f478af532d5b3c52f9db'), ObjectId('6626f478af532d5b3c52f9dc'), ObjectId('6626f478af532d5b3c52f9dd'), ObjectId('6626f478af532d5b3c52f9de'), ObjectId('6626f478af532d5b3c52f9df'), ObjectId('6626f478af532d5b3c52f9e0'), ObjectId('6626f478af532d5b3c52f9e1'), ObjectId('6626f478af532d5b3c52f9e2'), ObjectId('6626f478af532d5b3c52f9e3'), ObjectId('6626f478af532d5b3c52f9e4'), ObjectId('6626f478af532d5b3c52f9e5'), ObjectId('6626f478af532d5b3c52f9e6'), ObjectId('6626f478af532d5b3c52f9e7'), ObjectId('6626f478af532d5b3c52f9e8'), ObjectId('6626f478af532d5b3c52f9e9'), ObjectId('6626f478af532d5b3c52f9ea'), ObjectId('6626f478af532d5b3c52f9eb'), ObjectId('6626f478af532d5b3c52f9ec'), ObjectId('6626f478af532d5b3c52f9ed'), ObjectId('6626f478af532d5b3c52f9ee'), ObjectId('6626f478af532d5b3c52f9ef'), ObjectId('6626f478af532d5b3c52f9f0'), ObjectId('6626f478af532d5b3c52f9f1'), ObjectId('6626f478af532d5b3c52f9f2'), ObjectId('6626f478af532d5b3c52f9f3'), ObjectId('6626f478af532d5b3c52f9f4'), ObjectId('6626f478af532d5b3c52f9f5'), ObjectId('6626f478af532d5b3c52f9f6'), ObjectId('6626f478af532d5b3c52f9f7'), ObjectId('6626f478af532d5b3c52f9f8'), ObjectId('6626f478af532d5b3c52f9f9'), ObjectId('6626f478af532d5b3c52f9fa'), ObjectId('6626f478af532d5b3c52f9fb'), ObjectId('6626f478af532d5b3c52f9fc'), ObjectId('6626f478af532d5b3c52f9fd'), ObjectId('6626f478af532d5b3c52f9fe'), ObjectId('6626f478af532d5b3c52f9ff'), ObjectId('6626f478af532d5b3c52fa00')], acknowledged=True)

# %%
# List out the collections in the database
print(db.list_collection_names())
# Out:
# ['property_listings_info', 'schools_info', 'subway_stations_info']

# %%
# review a document in the collection
print(db.subway_stations_info.find_one())
# Out:
# {'_id': ObjectId('6626f478af532d5b3c52f9bb'), 'index': 0, 'Station': 'Finch TTC Subway Station', 'Address': '5600 Yonge Street', 'City': 'North York', 'Province': 'Ontario', 'Postal_code': 'M2N 5S2', 'Line': 1, 'Ridership_Weekly_Average': 102025, 'Parking_Spaces': 3227, 'Accessibility': 'Yes', 'LAT': 43.78055556, 'LON': -79.41472222, 'Coordinates': [43.78055556, -79.41472222]}

# %% [markdown]
# ## Attractions Data

# %%
def clean_properties(properties):
    """
    Cleaning the properties dictionary by removing specified fields and renaming 'ADDRESS_FULL'.
    """
    # List of property names to remove from the dictionary
    remove_fields = [
        'EMAIL', 'GEOID', 'RECEIVED_DATE', 'ADDRESS_POINT_ID', 'ADDRESS_NUMBER',
        'LINEAR_NAME_FULL', 'PLACE_NAME', 'LO_NUM', 'LO_NUM_SUF', 'HI_NUM',
        'HI_NUM_SUF', 'LINEAR_NAME_ID', 'WARD_2003', 'WARD_2018', 'MI_PRINX',
        'MUNICIPALITY', 'GENERAL_USE_CODE', 'CENTRELINE', 'WARD', 'ATTRACTION', 
        'MAP_ACCESS', 'ADDRESS_INFO'
    ]

    # Renaming 'ADDRESS_FULL' to 'Address' 
    cleaned_properties = {'Address': properties.pop('ADDRESS_FULL', None)}
    # Flatten geometry data
    # cleaned_properties['Geometry Type'] = geometry['type']
    # cleaned_properties['Coordinates'] = json.dumps(geometry['coordinates'])

    # Use dictionary comprehension to remove unwanted fields and update with geometry info
    cleaned_properties.update({key: value for key, value in properties.items() if key not in remove_fields})
    
    return cleaned_properties

# %%
def clean_geojson(geojson_data):
    """
    Iterating over all features in the GEOJSON data, cleaning properties and including geometry.
    """
    cleaned_features = []
    for feature in geojson_data['features']:
        # Clean properties of each feature
        feature['properties'] = clean_properties(feature['properties'])
        # Collect the cleaned features (currently commented out)
        # cleaned_features.append(cleaned_feature)

    # Replace original features with cleaned features (currently commented out)
    # geojson_data['features'] = cleaned_features
    return geojson_data

# %%
def export_to_csv(data, output_csv_path):
    """
    Exporting cleaned geojson data to a CSV file, including geometry information.
    """
    with open(output_csv_path, mode='w', newline='', encoding='utf-8') as csv_file:
        # Checking if there are features to export
        if data['features']:
            #Define the headers for the CSV file
            fieldnames = ['Address', 'Geometry Type', 'Coordinates']  # Add Geometry headers
            # Adding other property names as headers, excluding geometry fields for simplicity
            fieldnames += [key for key in data['features'][0]['properties'].keys() if key not in ('Address', 'Geometry Type', 'Coordinates')]
            writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
            writer.writeheader()
            # Writing each feature's properties to the CSV
            for feature in data['features']:
                writer.writerow(feature['properties'])

# %%
def print_json(data):
    """
    Print the JSON content of the cleaned data, including geometry information.
    """
    print(json.dumps(data, indent=4))

# %%
# Defining file paths
file_path = os.path.join('Data', 'Attractions.geojson')
output_csv_path = os.path.join('Data', 'Cleaned_Attractions.csv')
output_json_path = os.path.join('Data', 'Cleaned_Attractions.json')

try:
    with open(file_path, 'r') as file:
        geojson_data = json.load(file)
        
    # Cleaning the GEOJSON data
    cleaned_geojson_data = clean_geojson(geojson_data)

    # Export to CSV
    export_to_csv(cleaned_geojson_data, output_csv_path)
    print(f"Data has been exported to CSV at {output_csv_path}")

    # Export to JSON
    with open(output_json_path, 'w') as file:
        json.dump(cleaned_geojson_data, file, indent=4)
    print(f"Data has been exported to JSON at {output_json_path}")

except FileNotFoundError:
    print(f"The file {file_path} does not exist.")
except json.JSONDecodeError:
    print("Error decoding JSON from the file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data has been exported to CSV at Data\Cleaned_Attractions.csv
# Data has been exported to JSON at Data\Cleaned_Attractions.json

# %%
# MongoDB connection parameters
host = 'localhost'  # The server address where MongoDB is running
port = 27017         # The port on which MongoDB listens
dbname = 'real_estate_project_db' # The name of the database to connect to
collection_name = 'attractions_info'  # The name of the collection to insert data into

# Path to the cleaned JSON file
input_json_path = os.path.join('Data', 'Cleaned_Attractions.json')

# Connect to MongoDB
client = MongoClient(host, port)  # Create a MongoDB client
db = client[dbname]               # Select the database
collection = db[collection_name]  # Select the collection

# Loading the cleaned JSON data
with open(input_json_path, 'r') as file:  # Opening the JSON file for reading
    data = json.load(file)  # Loading JSON data from file
    # Extracting 'features' from data assuming it is structured for GeoJSON
    features = data.get('features', [])
    documents = [feature for feature in features]

# Inserting documents into the collection
collection.insert_many(documents) # Inserting all documents into the MongoDB collection
print(f"Data has been imported to MongoDB collection '{collection_name}' in database '{dbname}'.")

# Closing the connection to MongoDB
client.close()
# Out:
# Data has been imported to MongoDB collection 'attractions_info' in database 'real_estate_project_db'.

# %%
# List out the collections in the database
mongo = MongoClient(port=27017)
db = mongo['real_estate_project_db']  
print(db.list_collection_names())
# Out:
# ['property_listings_info', 'attractions_info', 'schools_info', 'subway_stations_info']

# %% [markdown]
# ![image.png](attachment:image.png)
