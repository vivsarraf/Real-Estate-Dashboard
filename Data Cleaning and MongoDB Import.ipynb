# %%
# Import dependencies
import requests
import pprint
import pandas as pd
import json
import os
import csv
from pymongo import MongoClient
from pprint import pprint

# %% [markdown]
# ## Property Listings Data

# %%
# Parameters for getting all the Property data from Houski Api
params = {}
params['api_key'] = '698c8c20-7e89-4f9b-a8c0-ac7fd9d76313'
params['city'] = 'toronto'
params['country_abbreviation'] = 'ca'
params['province_abbreviation'] = 'on'
params['results_per_page'] = '370'
params['select'] = 'address,latitude,longitude,city,province,postal_code,direction_facing,den,list_price,estimate_list_price,property_taxes,land_area_sq_m,interior_sq_m,bedroom,bathroom_full,bathroom_half,construction_year,property_taxes,score_education,score_food_and_drink,score_bicycle,score_entertainment,score_safety,score_shopping,score_traffic,score_transit,score_walkability'

# Make the API request
response = requests.get('https://api.houski.ca/properties', params=params)

# Extract the json result
if response.status_code == 200:
    json_data = response.json()
    pprint(json_data)
else:
    print(f'Failed to get data: {response}')
# Out:
# {'cache_hit': False,
#  'cost_cents': 965.6998901367188,
#  'data': [{'address': '2724 Lakeshore West',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 791440,
#            'interior_sq_m': 119.28750610351562,
#            'latitude': 43.603668212890625,
#            'longitude': -79.49807739257812,
#            'postal_code': 'V0V0V0',
#            'property_id': '38ff3c5f4f8e58bb',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '150 The Donway West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 518508,
#            'interior_sq_m': 82.31209564208984,
#            'latitude': 43.73347473144531,
#            'longitude': -79.3475112915039,
#            'postal_code': 'M3C0N8',
#            'property_id': 'd9d9af7de3bacd0a',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '260 Queens Quay West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 552618,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.6393928527832,
#            'longitude': -79.38575744628906,
#            'postal_code': 'M5V3M3',
#            'property_id': 'cf96a2504fe60838',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '701 Eglinton Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 634118,
#            'interior_sq_m': 72.83598327636719,
#            'latitude': 43.701820373535156,
#            'longitude': -79.42054748535156,
#            'postal_code': 'V0V0V0',
#            'property_id': '825d4687008d1521',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '697 Eglinton Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 632170,
#            'interior_sq_m': 90.85917663574219,
#            'latitude': 43.70195007324219,
#            'longitude': -79.4200210571289,
#            'postal_code': 'V0V0V0',
#            'property_id': 'e92ddd237ca39c5d',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2 Moraine Hill Drive Main',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 665359,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.77464294433594,
#            'longitude': -79.29815673828125,
#            'postal_code': 'V0V0V0',
#            'property_id': '464211196a182bb8',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '493 Clarens Avenue',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 488979,
#            'interior_sq_m': 55.741825103759766,
#            'latitude': 43.659912109375,
#            'longitude': -79.44204711914062,
#            'postal_code': 'V0V0V0',
#            'property_id': 'f6c5b7ba499dcb38',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '365 Eglinton Avenue East',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 689948,
#            'interior_sq_m': 64.10309600830078,
#            'latitude': 43.70909118652344,
#            'longitude': -79.38549041748047,
#            'postal_code': 'V0V0V0',
#            'property_id': 'b40d4b03d2b2360d',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3008 Queen Street East',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 677519,
#            'interior_sq_m': 68.84115600585938,
#            'latitude': 43.67543411254883,
#            'longitude': -79.27739715576172,
#            'postal_code': 'V0V0V0',
#            'property_id': 'b3d989bd2705ecd8',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1001 Cosburn Avenue Bsmt',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 665364,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.697174072265625,
#            'longitude': -79.31060028076172,
#            'postal_code': 'V0V0V0',
#            'property_id': '6d334c3eb134e984',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '560 Bathurst Street Bsmt',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 601183,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.658565521240234,
#            'longitude': -79.4087905883789,
#            'postal_code': 'V0V0V0',
#            'property_id': '5e39d7c6fb5c35f2',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '10 10 Laidlaw Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 488305,
#            'interior_sq_m': 46.45151901245117,
#            'latitude': 43.6397819519043,
#            'longitude': -79.42665100097656,
#            'postal_code': 'V0V0V0',
#            'property_id': 'a2a87b85d84498fa',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '551 Eglinton Avenue East',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 695078,
#            'interior_sq_m': 82.4979019165039,
#            'latitude': 43.710445404052734,
#            'longitude': -79.37863159179688,
#            'postal_code': 'V0V0V0',
#            'property_id': '795018d847499fcd',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '205 Danforth Avenue 2 Fl',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 575022,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.676631927490234,
#            'longitude': -79.3559799194336,
#            'postal_code': 'V0V0V0',
#            'property_id': 'ee017f98d4a06c89',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '22624 Eglinton Avenue East',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 528980,
#            'interior_sq_m': 74.32243347167969,
#            'latitude': 43.736419677734375,
#            'longitude': -79.25174713134766,
#            'postal_code': 'V0V0V0',
#            'property_id': '7a8aeecbc47a6dcb',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '22 Rusholme Park Crescent Main',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 493097,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.65227508544922,
#            'longitude': -79.42887878417969,
#            'postal_code': 'V0V0V0',
#            'property_id': 'd070b024a4cf9959',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '263 Dixon Roadd',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 437934,
#            'interior_sq_m': 65.0321273803711,
#            'latitude': 43.69526672363281,
#            'longitude': -79.54774475097656,
#            'postal_code': 'V0V0V0',
#            'property_id': '67c3790f65e2bbf4',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1120 Briar Hill Avenue C305',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 847667,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.70322799682617,
#            'longitude': -79.4512710571289,
#            'postal_code': 'V0V0V0',
#            'property_id': '1eac1a8cee28387c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '187 Rathburn Road Road E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1728013,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.6580924987793,
#            'longitude': -79.54960632324219,
#            'postal_code': 'V0V0V0',
#            'property_id': '71d46b72ff8ab757',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '800 Richmond Street West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 792455,
#            'interior_sq_m': 21.92511749267578,
#            'latitude': 43.644981384277344,
#            'longitude': -79.40995025634766,
#            'postal_code': 'V0V0V0',
#            'property_id': '756d21884ee11472',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '915 Street Clair Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 565914,
#            'interior_sq_m': 52.211509704589844,
#            'latitude': 43.67966079711914,
#            'longitude': -79.43392944335938,
#            'postal_code': 'V0V0V0',
#            'property_id': 'e290669c442c55d7',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '61 Clouston Avenue Lower',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 642115,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.6943244934082,
#            'longitude': -79.5072250366211,
#            'postal_code': 'V0V0V0',
#            'property_id': 'ca371fa3038141c',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '115 Livingstone Avenue Lower',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1002000,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.69765853881836,
#            'longitude': -79.44416809082031,
#            'postal_code': 'V0V0V0',
#            'property_id': '1b35245e07350dde',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '115 Eglinton Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 621279,
#            'interior_sq_m': 60.3869743347168,
#            'latitude': 43.70568084716797,
#            'longitude': -79.40211486816406,
#            'postal_code': 'V0V0V0',
#            'property_id': '9cf4cc1138f39029',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '7895 Jane Street',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 974593,
#            'interior_sq_m': 116.12879943847656,
#            'latitude': 43.79847717285156,
#            'longitude': -79.52503967285156,
#            'postal_code': 'V0V0V0',
#            'property_id': 'c7307e188972d3a0',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '82 Livingston Avenue',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1012014,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.69831466674805,
#            'longitude': -79.44276428222656,
#            'postal_code': 'V0V0V0',
#            'property_id': '416248aa9dcfe51b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '82 Livingstone Avenue Main',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1012014,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.69831466674805,
#            'longitude': -79.44276428222656,
#            'postal_code': 'V0V0V0',
#            'property_id': 'dfd3433dbdb653dd',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '220 Ellington Drive Main',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 668983,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.75785446166992,
#            'longitude': -79.2954330444336,
#            'postal_code': 'V0V0V0',
#            'property_id': 'fc43dd789d879089',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '32 Shouldice',
#            'bathroom_full': 2,
#            'bathroom_half': 1,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1404504,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.76335144042969,
#            'longitude': -79.3672103881836,
#            'postal_code': 'V0V0V0',
#            'property_id': '5eb446a0dbd9a476',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '30 Lambton Avenue Upper',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 962274,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.68386459350586,
#            'longitude': -79.4864730834961,
#            'postal_code': 'V0V0V0',
#            'property_id': '505d8aa297d16c6b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2 Moraine Hill Drive Lower',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 961015,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.77464294433594,
#            'longitude': -79.29815673828125,
#            'postal_code': 'V0V0V0',
#            'property_id': 'b67fa62ca16ced63',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '110 110 Maria Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 628605,
#            'interior_sq_m': 148.64486694335938,
#            'latitude': 43.66672897338867,
#            'longitude': -79.47660827636719,
#            'postal_code': 'V0V0V0',
#            'property_id': 'd92e7f8ec6111695',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1194 Royal York Road Bsmt',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 523381,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.66469192504883,
#            'longitude': -79.5194320678711,
#            'postal_code': 'V0V0V0',
#            'property_id': 'd2e922990666b904',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '30 Lambton Avenue Main',
#            'bathroom_full': 2,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1011478,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.68386459350586,
#            'longitude': -79.4864730834961,
#            'postal_code': 'V0V0V0',
#            'property_id': 'a8b70dbd3be67b8b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3541 Danforth Road',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 910646,
#            'interior_sq_m': 68.65534973144531,
#            'latitude': 43.69501495361328,
#            'longitude': -79.27589416503906,
#            'postal_code': 'M1J0A9',
#            'property_id': '5b098b745858fdce',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '771 Indian Road Main',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 554370,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.66309356689453,
#            'longitude': -79.45870971679688,
#            'postal_code': 'V0V0V0',
#            'property_id': '96ac05b538064731',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '917 Street Clair Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 626381,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.67962646484375,
#            'longitude': -79.43412780761719,
#            'postal_code': 'V0V0V0',
#            'property_id': '9ecce1d8368c6ee0',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '699 Eglinton Avenue West',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 528198,
#            'interior_sq_m': 58.06439971923828,
#            'latitude': 43.70185470581055,
#            'longitude': -79.42024230957031,
#            'postal_code': 'V0V0V0',
#            'property_id': '431224f04ffabc44',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '82 Livingstone Avenue Upper',
#            'bathroom_full': 1,
#            'bathroom_half': 1,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1012014,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.69831466674805,
#            'longitude': -79.44276428222656,
#            'postal_code': 'V0V0V0',
#            'property_id': '178e483c7b6a33d6',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '617 100 Dundalk Drive',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 456247,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.77027893066406,
#            'longitude': -79.28716278076172,
#            'postal_code': 'M1P4V2',
#            'property_id': '530a0ec0785db773',
#            'property_taxes': 912,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2503 2269 Lake Shore Boulevard W',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 889112,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.619632720947266,
#            'longitude': -79.48429870605469,
#            'postal_code': 'M8V3X6',
#            'property_id': '5121b044a41e773',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1510 3121 Sheppard Avenue E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 745634,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.7762565612793,
#            'longitude': -79.31668853759766,
#            'postal_code': 'M1T3J7',
#            'property_id': '58ee1379881bcff5',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '405 60 Brian Harrison Way',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 547550,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.77400207519531,
#            'longitude': -79.25758361816406,
#            'postal_code': 'M1P5J5',
#            'property_id': '784c469be40060e9',
#            'property_taxes': 1525,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3401 15 Mercer Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 813705,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.64556884765625,
#            'longitude': -79.39015197753906,
#            'postal_code': 'M5V1H2',
#            'property_id': 'f07410e447c8d423',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2010 2050 Bridletowne Circle',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 612983,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.79777908325195,
#            'longitude': -79.31342315673828,
#            'postal_code': 'M1W2V5',
#            'property_id': '3e9511aacad867ac',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '13A 570 Wellington Street W',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1027123,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.642818450927734,
#            'longitude': -79.4030532836914,
#            'postal_code': 'M5V2X5',
#            'property_id': '41affe57fddff98b',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1108 102 Bloor Street W',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1359128,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.66959762573242,
#            'longitude': -79.3918228149414,
#            'postal_code': 'M5S1M8',
#            'property_id': '8e22282408db4750',
#            'property_taxes': 5358,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '303 660 Pape Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1096050,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.67755126953125,
#            'longitude': -79.3447265625,
#            'postal_code': 'M4K3S5',
#            'property_id': '4eb2ead84cc9bbfa',
#            'property_taxes': 3957,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': 'N201 455 Front Street E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 876602,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.65276336669922,
#            'longitude': -79.35650634765625,
#            'postal_code': 'M5A0G2',
#            'property_id': 'd205fc4b2df601d0',
#            'property_taxes': 3265,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '907 69 Lynn Williams Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 583940,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.63884735107422,
#            'longitude': -79.41555786132812,
#            'postal_code': 'M6K3R7',
#            'property_id': '702ef9137ccb243e',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '539 Dufferin Street E',
#            'bathroom_full': 3,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 2,
#            'direction_facing': 'South',
#            'estimate_list_price': 1389605,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.16815185546875,
#            'longitude': -79.25090789794922,
#            'postal_code': 'M6K1A8',
#            'property_id': '6c0f5db63f35a046',
#            'property_taxes': 5076,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '635 26 Gibbs Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 741419,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.63886260986328,
#            'longitude': -79.55830383300781,
#            'postal_code': 'M9B0E3',
#            'property_id': 'abeb964b4aa9d33f',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '507 28 Byng Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 771391,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.77702713012695,
#            'longitude': -79.41377258300781,
#            'postal_code': 'M2N7H4',
#            'property_id': '81df4518eb6a53e2',
#            'property_taxes': 2498,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '908 170 Sumach Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 659411,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.6602897644043,
#            'longitude': -79.36066436767578,
#            'postal_code': 'M5A0C3',
#            'property_id': '8954f8f9bd1ef4f1',
#            'property_taxes': 2658,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1608 575 Bloor Street E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1044659,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.671546936035156,
#            'longitude': -79.37255859375,
#            'postal_code': 'M4W0B2',
#            'property_id': '3ec015e6449ff669',
#            'property_taxes': 3760,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1009 155 Dalhousie Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1132181,
# ...
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2108 4101 Sheppard Avenue E',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 611336,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.78299331665039,
#            'longitude': -79.28338623046875,
#            'postal_code': 'M1S3H3',
#            'property_id': 'f38f258e8ae2765b',
#            'property_taxes': 1282,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '522 52 Forest Manor Road',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 628199,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.77333068847656,
#            'longitude': -79.34581756591797,
#            'postal_code': 'M2J1M6',
#            'property_id': 'a62ed28140e56818',
#            'property_taxes': 1998,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '206 99 John Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1158810,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.647438049316406,
#            'longitude': -79.38985443115234,
#            'postal_code': 'M5V0S6',
#            'property_id': 'dc50b48850010910',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': 'Path 05 50 McCaul Street',
#            'bathroom_full': 3,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1556537,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.65181350708008,
#            'longitude': -79.39064025878906,
#            'postal_code': 'M5T1V9',
#            'property_id': '94b9fb87fff26b18',
#            'property_taxes': 5513,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '807 55 De Boers Drive',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 593177,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.75112533569336,
#            'longitude': -79.46591186523438,
#            'postal_code': 'M3J0G5',
#            'property_id': 'a967b8c0a058e1a0',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '527 51 Lower Simcoe Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 633817,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.642093658447266,
#            'longitude': -79.38355255126953,
#            'postal_code': 'M5J3A2',
#            'property_id': 'daf58a62a5023f58',
#            'property_taxes': 2445,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2312 150 East Liberty Street',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 583054,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.638763427734375,
#            'longitude': -79.41624450683594,
#            'postal_code': 'M6K3R5',
#            'property_id': '19b2184058f0a3a',
#            'property_taxes': 2060,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '3504 99 Broadway Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1292980,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.70852279663086,
#            'longitude': -79.39208984375,
#            'postal_code': 'M4P0A3',
#            'property_id': 'faed87d828d26adf',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2603 255 Village Green Square',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 678546,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.779685974121094,
#            'longitude': -79.28260803222656,
#            'postal_code': 'M1S0L7',
#            'property_id': '7b3ceb59dca7b3a9',
#            'property_taxes': 2365,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '2702 375 King Street W',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 1220162,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.645748138427734,
#            'longitude': -79.39308166503906,
#            'postal_code': 'M5V1K5',
#            'property_id': '75b87f6d816e729',
#            'property_taxes': 4943,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': 'Ph01 117 McMahon Drive',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 0,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 493992,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.7673225402832,
#            'longitude': -79.37040710449219,
#            'postal_code': 'M2K2X9',
#            'property_id': '7c51ff6bd93e9ec8',
#            'property_taxes': 1712,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1903 88 Park Lawn Road',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 627355,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.624053955078125,
#            'longitude': -79.48571014404297,
#            'postal_code': 'M8Y0B5',
#            'property_id': '24cdfbc104518015',
#            'property_taxes': 2132,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '1320 30 Shore Breeze Drive',
#            'bathroom_full': 1,
#            'bathroom_half': 0,
#            'bedroom': 1,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 1,
#            'direction_facing': 'South',
#            'estimate_list_price': 725711,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.62380599975586,
#            'longitude': -79.47982788085938,
#            'postal_code': 'M8V0J1',
#            'property_id': '7b15b9ecc03c913c',
#            'property_taxes': 2725,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '215 68 Broadview Avenue',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 3,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1209154,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.657501220703125,
#            'longitude': -79.35015869140625,
#            'postal_code': 'M4M2E6',
#            'property_id': '6dd758be9844994a',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '911 33 Frederick Todd Way',
#            'bathroom_full': 3,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 1372136,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.71356201171875,
#            'longitude': -79.36067962646484,
#            'postal_code': 'M4G0C9',
#            'property_id': '89f39d292054bae',
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '204 3091 Dufferin Street',
#            'bathroom_full': 2,
#            'bathroom_half': 0,
#            'bedroom': 2,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 663584,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.71531295776367,
#            'longitude': -79.45462036132812,
#            'postal_code': 'M6A0C4',
#            'property_id': 'f30e7a8a439eaf0b',
#            'property_taxes': 2545,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9},
#           {'address': '8B 425 Walmer Road',
#            'bathroom_full': 4,
#            'bathroom_half': 0,
#            'bedroom': 4,
#            'city': 'Toronto',
#            'construction_year': 1978,
#            'den': 0,
#            'direction_facing': 'South',
#            'estimate_list_price': 2741990,
#            'interior_sq_m': 104.51000213623047,
#            'latitude': 43.68505859375,
#            'longitude': -79.41213989257812,
#            'postal_code': 'M5P2X9',
#            'property_id': 'c0969d52b6423c75',
#            'property_taxes': 8328,
#            'province': 'Ontario',
#            'score_bicycle': 9,
#            'score_education': 9,
#            'score_entertainment': 7,
#            'score_food_and_drink': 10,
#            'score_safety': 10,
#            'score_shopping': 10,
#            'score_traffic': 10,
#            'score_transit': 9,
#            'score_walkability': 9}],
#  'error': '',
#  'pagination': {'current_page': 1,
#                 'has_next_page': True,
#                 'has_previous_page': False,
#                 'page_total': 1508},
#  'price_quote': False,
#  'result_total': 557816,
#  'time_ms': 51,
#  'ui_info': {'city': 'Toronto',
#              'city_id': '6cdbdee2492718ed',
#              'city_link': 'ca/on/toronto',
#              'city_slug': 'toronto',
#              'country': 'Canada',
#              'country_abbreviation': 'CA',
#              'country_abbreviation_id': '9ace2b6431b7f1be',
#              'country_abbreviation_link': 'ca',
#              'country_slug': 'canada',
#              'province': 'Ontario',
#              'province_abbreviation': 'ON',
#              'province_abbreviation_id': '146699ee774499d3',
#              'province_abbreviation_link': 'ca/on',
#              'province_slug': 'ontario'}}

# %%
# Extract the data from Json
Property_data=json_data["data"]
print(Property_data)
# Out:
# [{'address': '2724 Lakeshore West', 'bathroom_full': 1, 'bathroom_half': 1, 'bedroom': 2, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 791440, 'interior_sq_m': 119.28750610351562, 'latitude': 43.603668212890625, 'longitude': -79.49807739257812, 'postal_code': 'V0V0V0', 'property_id': '38ff3c5f4f8e58bb', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '150 The Donway West', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 2, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 518508, 'interior_sq_m': 82.31209564208984, 'latitude': 43.73347473144531, 'longitude': -79.3475112915039, 'postal_code': 'M3C0N8', 'property_id': 'd9d9af7de3bacd0a', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '260 Queens Quay West', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 1, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 552618, 'interior_sq_m': 104.51000213623047, 'latitude': 43.6393928527832, 'longitude': -79.38575744628906, 'postal_code': 'M5V3M3', 'property_id': 'cf96a2504fe60838', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '701 Eglinton Avenue West', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 2, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 634118, 'interior_sq_m': 72.83598327636719, 'latitude': 43.701820373535156, 'longitude': -79.42054748535156, 'postal_code': 'V0V0V0', 'property_id': '825d4687008d1521', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '697 Eglinton Avenue West', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 2, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 632170, 'interior_sq_m': 90.85917663574219, 'latitude': 43.70195007324219, 'longitude': -79.4200210571289, 'postal_code': 'V0V0V0', 'property_id': 'e92ddd237ca39c5d', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '2 Moraine Hill Drive Main', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 3, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 665359, 'interior_sq_m': 104.51000213623047, 'latitude': 43.77464294433594, 'longitude': -79.29815673828125, 'postal_code': 'V0V0V0', 'property_id': '464211196a182bb8', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9, 'score_entertainment': 7, 'score_food_and_drink': 10, 'score_safety': 10, 'score_shopping': 10, 'score_traffic': 10, 'score_transit': 9, 'score_walkability': 9}, {'address': '493 Clarens Avenue', 'bathroom_full': 1, 'bathroom_half': 0, 'bedroom': 1, 'city': 'Toronto', 'construction_year': 1978, 'den': 0, 'direction_facing': 'South', 'estimate_list_price': 488979, 'interior_sq_m': 55.741825103759766, 'latitude': 43.659912109375, 'longitude': -79.44204711914062, 'postal_code': 'V0V0V0', 'property_id': 'f6c5b7ba499dcb38', 'province': 'Ontario', 'score_bicycle': 9, 'score_education': 9,  ...

# %%
# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')

# Create the Database in Mongo Db
db = client['real_estate_project_db']  

# Create the collection in MongoDB
collection = db['property_listings_info'] 

input_json_path = os.path.join('Data', 'data.json')
# Load JSON data
with open(input_json_path, 'r') as file:
    file_data = json.load(file)

# Insert data into the collection
# If file_data is a list of dictionaries
if isinstance(file_data, list):
    collection.insert_many(file_data)
else:
    collection.insert_one(file_data)

# %% [markdown]
# ## Toronto Schools Data

# %%
# Create the collection in MongoDB
collection = db['schools_info'] 

input_json_path = os.path.join('Data', 'toronto-schools.json')
# Load JSON data
with open(input_json_path, 'r') as file:
    file_data = json.load(file)

# Insert data into the collection
# If file_data is a list of dictionaries
if isinstance(file_data, list):
    collection.insert_many(file_data)
else:
    collection.insert_one(file_data)

# %%
# List out the collections in the database
print(db.list_collection_names())
# Out:
# ['property_listings_info', 'schools_info']

# %%
# review a document in the collection
print(db.schools_info.find_one())
# Out:
# {'_id': 2, 'OBJECTID': 2, 'GEO_ID': 524780, 'NAME': 'A R S ARMENIAN PRIVATE SCHOOL', 'SOURCE_ADDRESS': '50 HALLCROWN PL', 'SCHOOL_TYPE_DESC': 'Private', 'ADDRESS_POINT_ID': 524780, 'LINEAR_NAME_FULL': 'Hallcrown Pl', 'ADDRESS_FULL': '50 Hallcrown Pl', 'POSTAL_CODE': 'M2J 1P7', 'MUNICIPALITY': 'North York', 'CITY': 'Toronto', 'GENERAL_USE_CODE': 104008, 'LONG': -79.323156147744, 'LAT': 43.770053062482}

# %% [markdown]
# ## Subway Stations Data

# %%
# Set the column width
pd.options.display.max_colwidth = 200

# Read the dataset and store as pandas dataframe. 
stations = pd.read_excel("Data/TTC Subway Stations.xlsx")
stations.head()
# Out:
#    ID            Station            Category                  Address  \
# 0   1              Finch  TTC Subway Station        5600 Yonge Street
# 1   2  North York Centre  TTC Subway Station        5102 Yonge Street
# 2   3     Sheppard–Yonge  TTC Subway Station  20 Sheppard Avenue West
# 3   4         York Mills  TTC Subway Station        4015 Yonge Street
# 4   5           Lawrence  TTC Subway Station        3101 Yonge Street
#
#          CITY Postal Code Line        Grade  Ridership (2019[9] avg. weekday)  \
# 0  North York     M2N 5S2    1  Underground                            102025
# 1  North York     M2N 6L8    1  Underground                             31471
# 2  North York     M2N 5M9  1,4  Underground                            134076
# 3  North York     M5M 3G1    1  Underground                             28461
# 4     Toronto     M4N 3N1    1  Underground                             28041
#
#   Parking spaces[10]  ... LAT min LAT seconds  LAT direction  LAT decimal  \
# 0          3,227[13]  ...      46        50.0              N    43.780556
# 1                  0  ...      46         6.0              N    43.768333
# 2                  0  ...      45        41.0              N    43.761389
# 3                  0  ...      44        39.0              N    43.744167
# 4                  0  ...      43        30.0              N    43.725000
#
#           LON LON degree  LON min LON seconds  LON direction  LON decimal
# 0  79°24?53?W         79       24        53.0              W   -79.414722
# 1  79°24?46?W         79       24        46.0              W   -79.412778
# 2  79°24?39?W         79       24        39.0              W   -79.410833
# 3  79°24?24?W         79       24        24.0              W   -79.406667
# 4   79°24?8?W         79       24         8.0              W   -79.402222
#
# [5 rows x 23 columns]

# %%
# Rename columns
stations.rename(columns={'CITY': "City",
                            'Ridership (2019[9] avg. weekday)': "Ridership_Weekly_Average",
                            'Parking spaces[10]': "Parking_Spaces",
                            'Accessible[12]': "Accessibility",
                            'Postal Code': 'Postal_code',
                            'LAT': 'LAT coordinate',
                            'LON': 'LON coordinate',
                            'LAT decimal': "LAT",
                            'LON decimal': "LON"}, inplace=True)

# Update station name to include 'TTC Subway Station' so 'Category' column can be removed
stations['Station'] = stations['Station'] + ' TTC Subway Station'

# Create new column to include province
stations['Province'] = 'Ontario'

# %%
# Trim the reference info from the parking space count
stations['Parking_Spaces'] = stations['Parking_Spaces'].str[:-4]

# Remove comma from the parking space count to prepare for integer conversion
# Fill in the NAN columns with 0 values instead
# Convert parking space count to integer
stations['Parking_Spaces'] = stations['Parking_Spaces'].str.replace(",","").fillna(0).astype(int)

# Confrm columns have been cleaned and identify the necessary ones only for export to mongodb
stations.dtypes
# Out:
# ID                            int64
# Station                      object
# Category                     object
# Address                      object
# City                         object
# Postal_code                  object
# Line                         object
# Grade                        object
# Ridership_Weekly_Average      int64
# Parking_Spaces                int32
# Accessibility                object
# LAT coordinate               object
# LAT degree                    int64
# LAT min                       int64
# LAT seconds                 float64
# LAT direction                object
# LAT                         float64
# LON coordinate               object
# LON degree                    int64
# LON min                       int64
# LON seconds                 float64
# LON direction                object
# LON                         float64
# Province                     object
# dtype: object

# %%
# Update dataframe to include only the necessary columns for the MongoDB export
stations = stations[['Station','Address', 'City', 'Province', 'Postal_code','Line','Ridership_Weekly_Average', 'Parking_Spaces','Accessibility', 'LAT', 'LON']]

# Print to confirm data has been cleaned
stations.head()
# Out:
#                                 Station                  Address        City  \
# 0              Finch TTC Subway Station        5600 Yonge Street  North York
# 1  North York Centre TTC Subway Station        5102 Yonge Street  North York
# 2     Sheppard–Yonge TTC Subway Station  20 Sheppard Avenue West  North York
# 3         York Mills TTC Subway Station        4015 Yonge Street  North York
# 4           Lawrence TTC Subway Station        3101 Yonge Street     Toronto
#
#   Province Postal_code Line  Ridership_Weekly_Average  Parking_Spaces  \
# 0  Ontario     M2N 5S2    1                    102025            3227
# 1  Ontario     M2N 6L8    1                     31471               0
# 2  Ontario     M2N 5M9  1,4                    134076               0
# 3  Ontario     M5M 3G1    1                     28461               0
# 4  Ontario     M4N 3N1    1                     28041               0
#
#   Accessibility        LAT        LON
# 0           Yes  43.780556 -79.414722
# 1           Yes  43.768333 -79.412778
# 2           Yes  43.761389 -79.410833
# 3           Yes  43.744167 -79.406667
# 4            No  43.725000 -79.402222

# %%
# Assign the collection to a variable
ttc_subway = db['subway_stations_info']

# %%
# Convert the dataframe to dictionary values and insert all entries into the specified collection
stations.reset_index(inplace=True)
data_dict = stations.to_dict("records")
ttc_subway.insert_many(data_dict)
# Out:
# InsertManyResult([ObjectId('6627d912296e4b6fde522675'), ObjectId('6627d912296e4b6fde522676'), ObjectId('6627d912296e4b6fde522677'), ObjectId('6627d912296e4b6fde522678'), ObjectId('6627d912296e4b6fde522679'), ObjectId('6627d912296e4b6fde52267a'), ObjectId('6627d912296e4b6fde52267b'), ObjectId('6627d912296e4b6fde52267c'), ObjectId('6627d912296e4b6fde52267d'), ObjectId('6627d912296e4b6fde52267e'), ObjectId('6627d912296e4b6fde52267f'), ObjectId('6627d912296e4b6fde522680'), ObjectId('6627d912296e4b6fde522681'), ObjectId('6627d912296e4b6fde522682'), ObjectId('6627d912296e4b6fde522683'), ObjectId('6627d912296e4b6fde522684'), ObjectId('6627d912296e4b6fde522685'), ObjectId('6627d912296e4b6fde522686'), ObjectId('6627d912296e4b6fde522687'), ObjectId('6627d912296e4b6fde522688'), ObjectId('6627d912296e4b6fde522689'), ObjectId('6627d912296e4b6fde52268a'), ObjectId('6627d912296e4b6fde52268b'), ObjectId('6627d912296e4b6fde52268c'), ObjectId('6627d912296e4b6fde52268d'), ObjectId('6627d912296e4b6fde52268e'), ObjectId('6627d912296e4b6fde52268f'), ObjectId('6627d912296e4b6fde522690'), ObjectId('6627d912296e4b6fde522691'), ObjectId('6627d912296e4b6fde522692'), ObjectId('6627d912296e4b6fde522693'), ObjectId('6627d912296e4b6fde522694'), ObjectId('6627d912296e4b6fde522695'), ObjectId('6627d912296e4b6fde522696'), ObjectId('6627d912296e4b6fde522697'), ObjectId('6627d912296e4b6fde522698'), ObjectId('6627d912296e4b6fde522699'), ObjectId('6627d912296e4b6fde52269a'), ObjectId('6627d912296e4b6fde52269b'), ObjectId('6627d912296e4b6fde52269c'), ObjectId('6627d912296e4b6fde52269d'), ObjectId('6627d912296e4b6fde52269e'), ObjectId('6627d912296e4b6fde52269f'), ObjectId('6627d912296e4b6fde5226a0'), ObjectId('6627d912296e4b6fde5226a1'), ObjectId('6627d912296e4b6fde5226a2'), ObjectId('6627d912296e4b6fde5226a3'), ObjectId('6627d912296e4b6fde5226a4'), ObjectId('6627d912296e4b6fde5226a5'), ObjectId('6627d912296e4b6fde5226a6'), ObjectId('6627d912296e4b6fde5226a7'), ObjectId('6627d912296e4b6fde5226a8'), ObjectId('6627d912296e4b6fde5226a9'), ObjectId('6627d912296e4b6fde5226aa'), ObjectId('6627d912296e4b6fde5226ab'), ObjectId('6627d912296e4b6fde5226ac'), ObjectId('6627d912296e4b6fde5226ad'), ObjectId('6627d912296e4b6fde5226ae'), ObjectId('6627d912296e4b6fde5226af'), ObjectId('6627d912296e4b6fde5226b0'), ObjectId('6627d912296e4b6fde5226b1'), ObjectId('6627d912296e4b6fde5226b2'), ObjectId('6627d912296e4b6fde5226b3'), ObjectId('6627d912296e4b6fde5226b4'), ObjectId('6627d912296e4b6fde5226b5'), ObjectId('6627d912296e4b6fde5226b6'), ObjectId('6627d912296e4b6fde5226b7'), ObjectId('6627d912296e4b6fde5226b8'), ObjectId('6627d912296e4b6fde5226b9'), ObjectId('6627d912296e4b6fde5226ba')], acknowledged=True)

# %%
# List out the collections in the database
print(db.list_collection_names())
# Out:
# ['property_listings_info', 'subway_stations_info', 'schools_info']

# %%
# review a document in the collection
print(db.subway_stations_info.find_one())
# Out:
# {'_id': ObjectId('6627d912296e4b6fde522675'), 'index': 0, 'Station': 'Finch TTC Subway Station', 'Address': '5600 Yonge Street', 'City': 'North York', 'Province': 'Ontario', 'Postal_code': 'M2N 5S2', 'Line': 1, 'Ridership_Weekly_Average': 102025, 'Parking_Spaces': 3227, 'Accessibility': 'Yes', 'LAT': 43.78055556, 'LON': -79.41472222}

# %% [markdown]
# ## Attractions Data

# %%
# Cleaning the properties dictionary by removing specified fields and renaming 'ADDRESS_FULL'.
def clean_properties(properties):  
    # List of property names to remove from the dictionary
    remove_fields = [
        'EMAIL', 'GEOID', 'RECEIVED_DATE', 'ADDRESS_POINT_ID', 'ADDRESS_NUMBER',
        'LINEAR_NAME_FULL', 'PLACE_NAME', 'LO_NUM', 'LO_NUM_SUF', 'HI_NUM',
        'HI_NUM_SUF', 'LINEAR_NAME_ID', 'WARD_2003', 'WARD_2018', 'MI_PRINX',
        'MUNICIPALITY', 'GENERAL_USE_CODE', 'CENTRELINE', 'WARD', 'ATTRACTION', 
        'MAP_ACCESS', 'ADDRESS_INFO'
    ]

    # Renaming 'ADDRESS_FULL' to 'Address' 
    cleaned_properties = {'Address': properties.pop('ADDRESS_FULL', None)}
    # Flatten geometry data
    # cleaned_properties['Geometry Type'] = geometry['type']
    # cleaned_properties['Coordinates'] = json.dumps(geometry['coordinates'])

    # Use dictionary comprehension to remove unwanted fields and update with geometry info
    cleaned_properties.update({key: value for key, value in properties.items() if key not in remove_fields})
    
    return cleaned_properties

# %%
# Iterating over all features in the GEOJSON data, cleaning properties and including geometry.
def clean_geojson(geojson_data):
    cleaned_features = []
    for feature in geojson_data['features']:
        # Clean properties of each feature
        feature['properties'] = clean_properties(feature['properties'])
        # Collect the cleaned features (currently commented out)
        # cleaned_features.append(cleaned_feature)

    # Replace original features with cleaned features (currently commented out)
    # geojson_data['features'] = cleaned_features
    return geojson_data

# %%
# Exporting cleaned geojson data to a CSV file, including geometry information.
def export_to_csv(data, output_csv_path):
    with open(output_csv_path, mode='w', newline='', encoding='utf-8') as csv_file:
        # Checking if there are features to export
        if data['features']:
            #Define the headers for the CSV file
            fieldnames = ['Address', 'Geometry Type', 'Coordinates']  # Add Geometry headers
            # Adding other property names as headers, excluding geometry fields for simplicity
            fieldnames += [key for key in data['features'][0]['properties'].keys() if key not in ('Address', 'Geometry Type', 'Coordinates')]
            writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
            writer.writeheader()
            # Writing each feature's properties to the CSV
            for feature in data['features']:
                writer.writerow(feature['properties'])

# %%
# Print the JSON content of the cleaned data, including geometry information.
def print_json(data):
    print(json.dumps(data, indent=4))

# %%
# Defining file paths
file_path = os.path.join('Data', 'Attractions.geojson')
output_csv_path = os.path.join('Data', 'Cleaned_Attractions.csv')
output_json_path = os.path.join('Data', 'Cleaned_Attractions.json')

try:
    with open(file_path, 'r') as file:
        geojson_data = json.load(file)
        
    # Cleaning the GEOJSON data
    cleaned_geojson_data = clean_geojson(geojson_data)

    # Export to CSV
    export_to_csv(cleaned_geojson_data, output_csv_path)
    print(f"Data has been exported to CSV at {output_csv_path}")

    # Export to JSON
    with open(output_json_path, 'w') as file:
        json.dump(cleaned_geojson_data, file, indent=4)
    print(f"Data has been exported to JSON at {output_json_path}")

except FileNotFoundError:
    print(f"The file {file_path} does not exist.")
except json.JSONDecodeError:
    print("Error decoding JSON from the file.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data has been exported to CSV at Data\Cleaned_Attractions.csv
# Data has been exported to JSON at Data\Cleaned_Attractions.json

# %%
# Path to the cleaned JSON file
input_json_path = os.path.join('Data', 'Cleaned_Attractions.json')

# Connect to MongoDB
collection = db['attractions_info']  # Select the collection

# Loading the cleaned JSON data
with open(input_json_path, 'r') as file:  # Opening the JSON file for reading
    data = json.load(file)  # Loading JSON data from file
    # Extracting 'features' from data assuming it is structured for GeoJSON
    features = data.get('features', [])
    documents = [feature for feature in features]

# Inserting documents into the collection
collection.insert_many(documents) # Inserting all documents into the MongoDB collection
print(f"Data has been imported to MongoDB collection attractions_info'.")
# Out:
# Data has been imported to MongoDB collection attractions_info'.

# %%
# List out the collections in the database
mongo = MongoClient(port=27017)
db = mongo['real_estate_project_db']  
print(db.list_collection_names())

# Closing the connection to MongoDB
client.close()
# Out:
# ['attractions_info', 'property_listings_info', 'subway_stations_info', 'schools_info']

# %% [markdown]
# ![image.png](attachment:image.png)
